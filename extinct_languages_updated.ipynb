# %%
import pandas as pd 

data = pd.read_csv('Extinct languages - DATA SUMMARY.csv')
# Out:
# /var/folders/gl/l6pb7jfx42l02zc9950kh3fh0000gn/T/ipykernel_707/1631123883.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data
# Out:
#      Name in English  Number of speakers Degree of endangerment
# 0      South Italian             7500000             Vulnerable
# 1           Sicilian             5000000             Vulnerable
# 2          Low Saxon             4800000             Vulnerable
# 3         Belarusian             4000000             Vulnerable
# 4            Lombard             3500000  Definitely endangered
# ...              ...                 ...                    ...
# 2534          |'Auni                   0                Extinct
# 2535            |Xam                   0                Extinct
# 2536         ǁKu ǁ'e                   0                Extinct
# 2537          ǁKx'au                   0                Extinct
# 2538          ǁXegwi                   0                Extinct
#
# [2539 rows x 3 columns]

# %%
# 'South Italian',
data.at[0, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/South_Italian'
#  'Sicilian',
data.at[1, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sicilian_language'
#  'Low Saxon',
data.at[2, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Low_Saxon_language'
#  'Belarusian',
data.at[3, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Belarusian_language'
#  'Lombard',
data.at[4, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lombard_language'
#  'Romani',
data.at[5, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Romani_language'
#  'Yiddish (Israel)',
data.at[6, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yiddish_language'
#  'Gondi',
data.at[7, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gondi_language'
#  'Limburgian-Ripuarian',
data.at[8, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limburgish_language'
#  'Quechua of Southern Bolivia',
data.at[9, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Kumaoni',
data.at[10, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kumaoni_language'
#  'Aymara',
data.at[11, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aymara_language'
#  'Emilian-Romagnol',
data.at[12, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Emilian-Romagnol_language'
#  'Piedmontese',
data.at[13, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piedmontese_language'
#  'Venetian',
data.at[14, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Venetian_language'
#  'Zazaki',
data.at[15, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zazaki_language'
#  'Kurux (India)',
data.at[16, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
#  'Tamajeq',
data.at[17, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamajaq_language'
#  'Tulu',
data.at[18, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tulu_language'
#  'Kangdi',
data.at[19, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kangdi_language'
#  'Scots',
data.at[20, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Scots_language'
#  'Torlak',
data.at[21, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Torlakian_dialect'
#  'West Flemish',
data.at[22, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/West_Flemish'
#  'Bashkir',
data.at[23, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bashkir_language'
#  'Chechen',
data.at[24, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chechen_language'
#  'Chuvash',
data.at[25, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chuvash_language'
#  'Meithei',
data.at[26, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Meitei_language'
#  'Tamang',
data.at[27, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamang_language'
#  'Quechua of Cuzco',
data.at[28, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Eastern Slovak',
data.at[29, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Slovak_language'
#  'Ligurian',
data.at[30, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ligurian_language'
#  'Rusyn',
data.at[31, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rusyn_language'
#  'Talysh',
data.at[32, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Talysh_language'
#  'Kui',
data.at[33, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kui_language'
#  'Khasi',
data.at[34, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khasi_language'
#  'Bodo',
data.at[35, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bodo_language'
#  'Campidanese',
data.at[36, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Campidanese_Sardinian'
#  "K'iche' (Guatemala)",
data.at[37, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/K%27iche%27_language'
#  'Quechua of Ayacucho',
data.at[38, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Newar',
data.at[39, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Newar_language'
#  'Mon',
data.at[40, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mon_language'
#  'Polesian',
data.at[41, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Polesian_language'
#  'Tamaceq',
data.at[42, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamajaq_language'
#  'Avar',
data.at[43, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Avar_language'
#  'Mundari',
data.at[44, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mundari_language'
#  'Welsh',
data.at[45, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Welsh_language'
#  'Angika',
data.at[46, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Angika_language'
#  "Q'eqchi' (Guatemala)",
data.at[47, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Q%27eqchi%27_language'
#  'Picard',
data.at[48, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Picard_language'
#  'Kokborok',
data.at[49, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kokborok_language'
#  'Basque',
data.at[50, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Basque_language'
#  'Kabard-Cherkes',
data.at[51, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kabardian_language'
#  'Mandeali',
data.at[52, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mandeali_language'
#  'Friulian',
data.at[53, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Friulian_language'
#  'Quechua of Ancash and Huánuco',
data.at[54, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Walloon',
data.at[55, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Walloon_language'
#  'Mising',
data.at[56, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mising_language'
#  'Ossete',
data.at[57, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ossetian_language'
#  'Mizo',
data.at[58, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mizo_language'
#  'Dargwa',
data.at[59, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dargwa_language'
#  'Aromanian',
data.at[60, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aromanian_language'
#  'Brahui',
data.at[61, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Brahui_language'
#  'Languedocian',
data.at[62, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Languedocien_language'
#  'Lezgian',
data.at[63, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lezgian_language'
#  'Mahasui',
data.at[64, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mahasui_language'
#  'Magar',
data.at[65, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Magar_language'
#  'Mam (Guatemala)',
data.at[66, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mam_language'
#  'Udmurt',
data.at[67, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Udmurt_language'
#  'Huasteca Náhuatl',
data.at[68, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahuatl'
#  'Kumyk',
data.at[69, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kumyk_language'
#  'Yakut',
data.at[70, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yakut_language'
#  'Kaqchikel (Guatemala)',
data.at[71, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaqchikel_language'
#  'Karbi',
data.at[72, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karbi_language'
#  'Eastern Mari',
data.at[73, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mari_language'
#  'Ingush',
data.at[74, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ingush_language'
#  'Erzya',
data.at[75, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Erzya_language'
#  'Ho',
data.at[76, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ho_language'
#  'Judezmo (Israel)',
data.at[77, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Spanish'
#  'Lalo',
data.at[78, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lalo_language'
#  'Limousin',
data.at[79, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limousin_language'
#  'Logudorese',
data.at[80, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Logudorese_Sardinian'
#  'Mapuche (Chile)',
data.at[81, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mapuche_language'
#  'Central Náhuatl',
data.at[82, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahuatl'
#  'Moselle Franconian',
data.at[83, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moselle_Franconian_dialects'
#  'Bantawa',
data.at[84, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bantawa_language'
#  'Santa',
data.at[85, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Santa_language'
#  'Mingrelian',
data.at[86, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mingrelian_language'
#  'West Frisian',
data.at[87, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/West_Frisian_language'
#  'Gurung',
data.at[88, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gurung_language'
#  'Guajiro',
data.at[89, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wayuu_language'
#  'Karachay-Balkar',
data.at[90, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karachay-Balkar_language'
#  'Adyge',
data.at[91, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Adyghe_language'
#  'Buryat (Trans-Baikal)',
data.at[92, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buryat_language'
#  'Kurru',
data.at[93, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurru_language'
#  'Kuvi',
data.at[94, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuvi_language'
#  'Limbu',
data.at[95, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limbu_language'
#  'Moroccan Judeo-Arabic (Israel)',
data.at[96, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Moroccan_Arabic#:~:text=Widely%20used%20in%20the%20Jewish,from%20Spain%20after%20the%201492'
#  'Plautdietsch',
data.at[97, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Plautdietsch_language'
#  'Pontic Greek',
data.at[98, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pontic_Greek'
#  'Quichua (Cotopaxi, Tungurahua and Chimborazo)',
data.at[99, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'

# %%
# 'Quechua of Santiago del Estero',
data.at[100, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Svan',
data.at[101, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Svan_language'
#  'Tai Daeng',
data.at[102, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tai_Daeng_language'
#  'Taznatit',
data.at[103, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taznatit_language'
#  'Razihi',
data.at[104, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Razihi_language'
#  'Wakhi',
data.at[105, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wakhi_language'
#  'Bishnupriya Manipuri Creole',
data.at[106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bishnupriya_Manipuri_language'
#  'Acheron',
data.at[107, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Acheron_language'
#  'Maori',
data.at[108, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/M%C4%81ori_language'
#  'Tai Neua',
data.at[109, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tai_Neua_language'
#  'Bhadravahi',
data.at[110, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bhadravahi_language'
#  'Kinnauri',
data.at[111, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kinnauri_language'
#  'Gallo-Sicilian',
data.at[112, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sicilian_language'
#  'Kurux (Bangladesh)',
data.at[113, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
#  "Tz'utujil",
data.at[114, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tz%27utujil_language'
#  'Chamorro',
data.at[115, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chamorro_language'
#  'Ashaninka (Peru)',
data.at[116, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ashaninka_language'
#  'Chang',
data.at[117, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chang_language'
#  'Kuna (Panama)',
data.at[118, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuna_language'
#  'Churahi',
data.at[119, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Churahi_language'
#  'Nruanghmei',
data.at[120, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nruanghmei_language'
#  'Rengma',
data.at[121, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rengma_language'
#  'Faroese',
data.at[122, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Faroese_language'
#  'Northern Tujia',
data.at[123, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tujia_language'
#  'Torwali',
data.at[124, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Torwali_language'
#  'Chuj (Guatemala)',
data.at[125, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chuj_language'
#  'Kachari',
data.at[126, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kachari_language'
#  'Scottish Gaelic',
data.at[127, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Scottish_Gaelic'
#  'Sierra de Puebla Náhuatl',
data.at[128, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahuatl'
#  'Limonese Creole',
data.at[129, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limonese_Creole'
#  'Kashubian',
data.at[130, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kashubian_language'
#  'Khakas',
data.at[131, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khakas_language'
#  'Parji',
data.at[132, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Parji_language'
#  'Arvanitika',
data.at[133, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arvanitika'
#  'Buryat (Cis-Baikal)',
data.at[134, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buryat_language'
#  'Buryat (Manchuria)',
data.at[135, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Takpa_language'
#  'Cuona Menba',
data.at[136, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cuona_language'
#  'Eastern Cham',
data.at[137, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cham_language'
#  'Hmar',
data.at[138, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hmar_language'
#  'Huzhu Monguor',
data.at[139, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Monguor_language'
#  'Paite',
data.at[140, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Paite_language'
#  'Quichua (Imbabura)',
data.at[141, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Soqotri',
data.at[142, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Soqotri_language'
#  'Southern Altay',
data.at[143, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Altay_language'
#  'Transylvanian Saxon',
data.at[144, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Transylvanian_Saxon_dialect'
#  'Turoyo',
data.at[145, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Turoyo_language'
#  'Võro-Seto',
data.at[146, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/V%C3%B5ro_language'
#  'West Greenlandic',
data.at[147, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/West_Greenlandic'
#  'Western Armenian (Turkey)',
data.at[148, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Western_Armenian'
#  'Zaramo',
data.at[149, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zaramo_language'
#  'Zenatiya',
data.at[150, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Eastern_Morocco_Zenati'
#  'Papantla Totonac',
data.at[151, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Totonac_language'
#  'Wancho',
data.at[152, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wancho_language'
#  'Bhumji',
data.at[153, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bhumji_language'
#  'Cosung (China)',
data.at[154, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cosung_language'
#  'Cosung (Viet Nam)',
data.at[155, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cosung_language'
#  'Baheng (China)',
data.at[156, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baheng_language'
#  'Lumun',
data.at[157, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lumun_language'
#  'Quichua (Loja)',
data.at[158, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Chamling',
data.at[159, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chamling_language'
#  'Irish',
data.at[160, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Irish_language'
#  'Reshe',
data.at[161, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Reshe_language'
#  'Sierra Otomí',
data.at[162, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Otomi_language'
#  'Phuthi',
data.at[163, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phuthi_language'
#  'Rarotongan',
data.at[164, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rarotongan_language'
#  'Khalaj',
data.at[165, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khalaj_language'
#  'Dungan',
data.at[166, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dungan_language'
#  'Kheza',
data.at[167, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kheza_language'
#  'Jola-Kassa',
data.at[168, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jola-Kasa_language'
#  'Satār',
data.at[169, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Satar_language'
#  'Guaraní Boliviano',
data.at[170, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guarani_language'
#  'Gutob',
data.at[171, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gutob_language'
#  'Kheng',
data.at[172, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kheng_language'
#  'Laro',
data.at[173, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laro_language'
#  'Minyong',
data.at[174, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Minyong_language'
#  'Mru',
data.at[175, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mru_language'
#  'Patani Malay',
data.at[176, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pattani_Malay'
#  'Quechua of Cajatambo, Pasco and northern Junín',
data.at[177, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Quichua (Napo)',
data.at[178, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Tangsa',
data.at[179, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tangsa_language'
#  'Tetserret',
data.at[180, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tetserret_language'
#  'Awajun',
data.at[181, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aguaruna_language#:~:text=Aguaruna%20(or%20as%20native%20speakers,Aguaruna%20people%20in%20Northern%20Peru'
#  'Khiamngan',
data.at[182, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khiamngan_language'
#  'Ngile',
data.at[183, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngile_language'
#  'Phunoi',
data.at[184, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phunoi_language'
#  'Lower Mixe',
data.at[185, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mixe_languages'
#  'Maram',
data.at[186, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maram_language'
#  'Western Mari',
data.at[187, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mari_language'
#  'Chepang',
data.at[188, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chepang_language'
#  'Chontal Tabasco',
data.at[189, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chontal_Maya_language'
#  'Muji',
data.at[190, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Muji_language'
#  'Akatek (Guatemala)',
data.at[191, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Akatek_language'
#  'Huichol',
data.at[192, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Huichol_language'
#  'Romansh',
data.at[193, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Romansh_language'
#  'Apatani',
data.at[194, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Apatani_language'
#  'Galo',
data.at[195, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Galo_language'
#  'Korwa',
data.at[196, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Korwa_language'
#  'Shuar chicham',
data.at[197, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shuar_language'
#  'Ticuna',
data.at[198, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ticuna_language'
#  'Wanka Quechua',
data.at[199, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Sikuani'
data.at[200, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sikuani_language'

# %%
# 'Sikuani',
data.at[200, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sikuani_language'
#  'Jakaltek (Guatemala)',
data.at[201, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jakaltek_language'
#  'Liangmai',
data.at[202, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Liangmai_language'
#  'Zeme',
data.at[203, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zeme_language'
#  'Highland Mazatec',
data.at[204, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mazatec_language'
#  'Thangmi',
data.at[205, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Thangmi_language'
#  'Nocte',
data.at[206, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nocte_language'
#  'Mayo',
data.at[207, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mayo_language'
#  'Lauje',
data.at[208, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lauje_language'
#  'Danuwar',
data.at[209, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Danuwar_language'
#  'Sirmaudi',
data.at[210, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sirmauri_language'
#  'Abaza',
data.at[211, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Abaza_language'
#  'Koch',
data.at[212, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koch_language'
#  'Amis',
data.at[213, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Amis_language'
#  'Biak',
data.at[214, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Biak_language'
#  'Bumthang',
data.at[215, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bumthang_language'
#  'Burgenland Croatian',
data.at[216, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Burgenland_Croatian'
#  'Dzhidi',
data.at[217, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dzhidi_language'
#  'Judeo-Berber (Israel)',
data.at[218, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Berber_language'
#  'Kham',
data.at[219, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kham_language'
#  'Ladin',
data.at[220, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ladin_language'
#  'Lepcha',
data.at[221, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lepcha_language'
#  'Maonan',
data.at[222, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maonan_language'
#  'Mok (Myanmar, Thailand)',
data.at[223, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mok_language'
#  'Moro',
data.at[224, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moro_language'
#  'Mulam',
data.at[225, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mulam_language'
#  'North Saami',
data.at[226, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Sami'
#  'Quechua of Cajamarca',
data.at[227, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Quichua (Pastaza)',
data.at[228, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
#  'Rushani',
data.at[229, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rushani_language'
#  'Tagin',
data.at[230, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tagin_language'
#  'Tialo',
data.at[231, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tialo_language'
#  'Tidikelt',
data.at[232, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tidikelt_language'
#  'Toba',
data.at[233, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Toba_language'
#  'Tundra Nenets',
data.at[234, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nenets_language'
#  'Vojvodina Rusyn',
data.at[235, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rusyn_language'
#  'Wuse',
data.at[236, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wuse_language'
#  'Agul',
data.at[237, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Agul_language'
#  'Rutul',
data.at[238, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rutul_language'
#  'Bateri',
data.at[239, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bateri_language'
#  'Mzieme',
data.at[240, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mzieme_language'
#  'Ghale',
data.at[241, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ghale_language'
#  'Sierra Popoluca',
data.at[242, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Popoluca_language'
#  'Kurux (Nepal)',
data.at[243, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
#  'Deori',
data.at[244, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Deori_language'
#  'Soyaltepec Mazatec',
data.at[245, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mazatec_language'
#  'Western Mazahua',
data.at[246, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mazahua_language'
#  'Sibe',
data.at[247, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sibe_language'
#  'Isthmus Náhuatl',
data.at[248, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahuatl'
#  'Sunwar',
data.at[249, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sunwar_language'
#  'Mancagne',
data.at[250, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mancagne_language'
#  'Gadaba',
data.at[251, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gadaba_language'
#  'Banat Bulgarian',
data.at[252, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Banat_Bulgarian_dialect'
#  'Csángó Hungarian',
data.at[253, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cs%C3%A1ng%C3%B3_language'
#  'Koda',
data.at[254, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koda_language'
#  'Minhe Monguor',
data.at[255, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Monguor_language'
#  'Miskito (Honduras)',
data.at[256, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miskito_language'
#  'Olonetsian',
data.at[257, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Olonetsian_language'
#  'Saek',
data.at[258, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Saek_language'
#  'Sioux',
data.at[259, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sioux_language'
#  'Tamazight (Beni Iznassen)',
data.at[260, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight'
#  'Tsakhur',
data.at[261, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tsakhur_language'
#  'Warao',
data.at[262, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Warao_language'
#  'Majhi',
data.at[263, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Majhi_language'
#  'Jone',
data.at[264, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jone_language'
#  'Andi',
data.at[265, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Andi_language'
#  'Guambiano',
data.at[266, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guambiano_language'
#  'Anal',
data.at[267, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Anal_language'
#  'Hawrami',
data.at[268, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hawrami_language'
#  'Juang',
data.at[269, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Juang_language'
#  'Tiwa',
data.at[270, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tiwa_language'
#  'Embera (Panama)',
data.at[271, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ember%C3%A1_language'
#  'Ediamat',
data.at[272, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ediamat_language'
#  'Mara',
data.at[273, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mara_language'
#  'Maring',
data.at[274, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maring_language'
#  'Polci cluster',
data.at[275, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Polci_language'
#  'Sarikoli',
data.at[276, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sarikoli_language'
#  'Krongo',
data.at[277, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Krongo_language'
#  'Ashtiani',
data.at[278, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ashtiani_language'
#  'Khunsari',
data.at[279, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khunsari_language'
#  'Semnani',
data.at[280, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Semnani_language'
#  'Plains Cree',
data.at[281, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Plains_Cree'
#  'Higher Reservoir Mazatec',
data.at[282, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mazatec_language'
#  'Chilchotla Mazatec',
data.at[283, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mazatec_language'
#  'Zapotec of the Valleys, middle northwest',
data.at[284, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zapotec_languages'
#  'Aluo',
data.at[285, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aluo_language'
#  'Bangni',
data.at[286, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bangni_language'
#  'Bru',
data.at[287, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bru_language'
#  'Cho-ca-nga-ca-kha',
data.at[288, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cho-ca-nga-ca-kha_language'
#  'Crimean Tatar (Dobruja)',
data.at[289, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Crimean_Tatar_language'
#  'Dhimal',
data.at[290, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dhimal_language'
#  'Griko (Salento)',
data.at[291, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Griko_dialect'
#  'Kaiowá Guarani',
data.at[292, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaiow%C3%A1_language'
#  'Karelian (Karelia)',
data.at[293, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karelian_language'
#  'Khoirao',
data.at[294, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khoirao_language'
#  'Manchad',
data.at[295, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manchad_language'
#  'Mariupolitan Greek',
data.at[296, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mariupolitan_Greek'
#  'Padam',
data.at[297, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Padam_language'
#  'Pemon (Venezuela)',
data.at[298, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pemon_language'
#  'Tacenwit',
data.at[299, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tacenwit_language'
#  'Tangwang'
data.at[300, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tangwang_language'

# %%
import requests

for link in data['Wikipedia URL'][200:300]:
    # get the response of the request
    if requests.get(link).status_code != 200:
        print(link)
# Out:
# https://en.wikipedia.org/wiki/Cs%C3%A1ng%C3%B3_language
# https://en.wikipedia.org/wiki/Cho-ca-nga-ca-kha_language
# https://en.wikipedia.org/wiki/Tacenwit_language

# %%
data['Name in English'].loc[300:400].to_list()
# Out:
# ['Sikuani',
#  'Jakaltek (Guatemala)',
#  'Liangmai',
#  'Zeme',
#  'Highland Mazatec',
#  'Thangmi',
#  'Nocte',
#  'Mayo',
#  'Lauje',
#  'Danuwar',
#  'Sirmaudi',
#  'Abaza',
#  'Koch',
#  'Amis',
#  'Biak',
#  'Bumthang',
#  'Burgenland Croatian',
#  'Dzhidi',
#  'Judeo-Berber (Israel)',
#  'Kham',
#  'Ladin',
#  'Lepcha',
#  'Maonan',
#  'Mok (Myanmar, Thailand)',
#  'Moro',
#  'Mulam',
#  'North Saami',
#  'Quechua of Cajamarca',
#  'Quichua (Pastaza)',
#  'Rushani',
#  'Tagin',
#  'Tialo',
#  'Tidikelt',
#  'Toba',
#  'Tundra Nenets',
#  'Vojvodina Rusyn',
#  'Wuse',
#  'Agul',
#  'Rutul',
#  'Bateri',
#  'Mzieme',
#  'Ghale',
#  'Sierra Popoluca',
#  'Kurux (Nepal)',
#  'Deori',
#  'Soyaltepec Mazatec',
#  'Western Mazahua',
#  'Sibe',
#  'Isthmus Náhuatl',
#  'Sunwar',
#  'Mancagne',
#  'Gadaba',
#  'Banat Bulgarian',
#  'Csángó Hungarian',
#  'Koda',
#  'Minhe Monguor',
#  'Miskito (Honduras)',
#  'Olonetsian',
#  'Saek',
#  'Sioux',
#  'Tamazight (Beni Iznassen)',
# ...

# %%
# data.at[0, 'Country/Region'] = ['Salento, Italy', 'Calabria, Italy', 'Sicily, Italy', 'Campania, Italy']
# data.at[0, 'LatLng'] = ['40.39419137452559, 17.963600660528844', '39.21416005602436, 16.537916008812285', '37.516227931820026, 14.345347283418377', '40.92014500456253, 14.986523067820155']
data.at[0, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Extreme_Southern_Italian']

# data.at[1, 'Country/Region'] = ['Sicily, Italy', 'Calabria, Italy', 'Apulia, Italy']
# data.at[1, 'LatLng'] = ['37.516227931820026, 14.345347283418377', '39.21416005602436, 16.537916008812285', '41.118686073813706, 16.305896215476736']
data.at[1, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Sicilian_language']

# data.at[2, 'Country/Region'] = ['Netherlands, northwestern Germany', 'southern Denmark']
# data.at[2, 'LatLng'] = ['52.165845449170654, 5.4496583209294815', '52.962838169929235, 8.205301857132776', '55.199844947118876, 9.077417189268257']
data.at[2, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Low_Saxon#:~:text=Low%20Saxon%20(Dutch%3A%20Nedersaksisch),the%20German%2Dspeaking%20minority).']

# data.at[3, 'Country/Region'] = ['Belarus']
# data.at[3, 'LatLng'] = '53.574198585592775, 28.147495124123935'
data.at[3, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Belarusian_language']

# data.at[4, 'Country/Region'] = ['Lombardy, Italy', 'Piedmont, Italy', 'South Tyrol, Italy', 'Trentino, Italy', 'Grisons, Switzerland', 'Ticino, Switzerland', 'Santa Catarina, Brazil']
# data.at[4, 'LatLng'] = ['45.66139176678368, 9.63227911823771', '45.01805632528342, 7.687020797919262', '46.68598171644191, 11.412589180055472', '46.1238049982629, 11.099939496230027', '46.70364951869676, 9.625764392545706', '46.24799575694668, 8.822916907755756', '-27.103445178016358, -50.60440492276544']
data.at[4, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Lombard_language']

# data.at[5, 'Country/Region'] = ['Romania', 'Bulgaria', 'North Macedonia', 'Slovakia']
# data.at[5, 'LatLng'] = ['45.9265107008262, 25.096806021387128', '42.58697312857569, 25.09051711347847', '41.68037836433533, 21.659217608349277', '48.736472499923366, 19.323017931230854']
data.at[5, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Romani_language']

# data.at[6, 'Country/Region'] = ['Israel']
# data.at[6, 'LatLng'] = ['30.964512492275226, 34.911527479070514']
data.at[6, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Yiddish']

# data.at[7, 'Country/Region'] = ['Madhya Pradesh, India', 'Maharashtra, India', 'Chhattisgarh, India', 'Andhra Pradesh, India', 'Telangana, India']
# data.at[7, 'LatLng'] = ['23.51668077101653, 78.6826448207132', '19.324648813790514, 75.22760358923988', '21.292723167751706, 81.98707478511837', '14.919637211506634, 79.21777918866634', '17.928676985304467, 79.07595393942451']
data.at[7, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Gondi_language']

# data.at[8, 'Country/Region'] = ['Germany', 'Belgium', 'Netherlands']
# data.at[8, 'LatLng'] = ['51.12521633891649, 10.402567288480906', '50.499010620952, 4.683092655020415', '52.16994537041243, 5.584451739288431']
data.at[8, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Ripuarian_language']

# data.at[9, 'Country/Region'] = ['Southern Bolivia']
# data.at[9, 'LatLng'] = ['-19.405157077688227, -64.56190216911811']
data.at[9, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Southern_Quechua']

# data.at[10, 'Country/Region'] = ['Kumaon Region, State of Uttarakhand, India', 'Doti Region, Nepal']
# data.at[10, 'LatLng'] = ['29.335096154163143, 79.48352101698042', '29.26364414817748, 80.91898566512845']
data.at[10, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Kumaoni_language']

# data.at[11, 'Country/Region'] = ['Bolivia', 'Peru', 'Chile']
# data.at[11, 'LatLng'] = ['-16.478968884118004, -64.47401155186418', '-10.542578607328185, -75.3724480913509', '-26.677601282889743, -70.27479229062325']
data.at[11, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Aymara_language']

# data.at[12, 'Country/Region'] = ['Emilia-Romagna', 'Marche', 'San Marino']
# data.at[12, 'LatLng'] = ['44.56480527292052, 11.38601678658859', '43.47640588091273, 13.176485227081479', '43.93666781145424, 12.453566282582253']
data.at[12, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Emilian%E2%80%93Romagnol_linguistic_group']

# data.at[13, 'Country/Region'] = ['Peidmont, Italy']
# data.at[13, 'LatLng'] = ['45.16968540759214, 7.763297257279384']
data.at[13, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Piedmontese_language']

data.at[14, 'Name in English'] = 'Venetian'
# data.at[14, 'Country/Region'] = ['Veneto, Italy', 'Friuli-Venezia Giulia, Italy', 'Istria, Croatia', 'Dalmatia, Croatia', 'Kvarner Gulf, Croatia']
# data.at[14, 'LatLng'] = ['45.58199841883966, 11.581490304348849', '46.1220148760741, 13.184887891792679', '45.2484098334152, 13.952746139359418', '43.575972746275006, 16.073608338609866', '45.30681708153201, 14.28031692985417']
data.at[14, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Venetian_language']

# data.at[15, 'Country/Region'] = ['Eastern Anatolia Region, Turkey']
# data.at[15, 'LatLng'] = ['36.568989230519925, 31.988986670944435']
data.at[15, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Zaza_language']

# data.at[16, 'Country/Region'] = ['Jarkhand, India', 'West Bengal, India']
# data.at[16, 'LatLng'] = ['23.767942333468756, 85.27802514765212', '23.063537111141578, 87.3293226598728']
data.at[16, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Kurukh_language']

# data.at[17, 'Country/Region'] = ['Aïr Mountains, Agadez Region, Niger']
# data.at[17, 'LatLng'] = ['18.281139578151937, 8.000514665382859']
data.at[17, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Air_Tamajeq_language']

# data.at[18, 'Country/Region'] = ['Dakshina Kannada, Karnataka, India', 'Kasaragod, Kerala, India']
# data.at[18, 'LatLng'] = ['12.904806568633338, 75.19842179832064', '12.499434190513837, 74.98580861660531']
data.at[18, 'Wikipedia Page'] = ['https://en.wikipedia.org/wiki/Tulu_language']

# data.at[19, 'Country/Region'] = []
# data.at[19, 'LatLng'] = []
# data.at[19, 'Wikipedia Page'] =

# data.at[20, 'Country/Region'] = []
# data.at[20, 'LatLng'] = []
# data.at[20, 'Wikipedia Page'] =

# data.at[21, 'Country/Region'] = []
# data.at[21, 'LatLng'] = []
# data.at[21, 'Wikipedia Page'] =

# data.at[22, 'Country/Region'] = []
# data.at[22, 'LatLng'] = []
# data.at[22, 'Wikipedia Page'] =

# data.at[23, 'Country/Region'] = []
# data.at[23, 'LatLng'] = []
# data.at[23, 'Wikipedia Page'] =

# data.at[24, 'Country/Region'] = []
# data.at[24, 'LatLng'] = []
# data.at[24, 'Wikipedia Page'] =

# data.at[25, 'Country/Region'] = []
# data.at[25, 'LatLng'] = []
# data.at[25, 'Wikipedia Page'] =



data
# Out:
#      Name in English  Number of speakers Degree of endangerment  \
# 0      South Italian             7500000             Vulnerable
# 1           Sicilian             5000000             Vulnerable
# 2          Low Saxon             4800000             Vulnerable
# 3         Belarusian             4000000             Vulnerable
# 4            Lombard             3500000  Definitely endangered
# ...              ...                 ...                    ...
# 2534          |'Auni                   0                Extinct
# 2535            |Xam                   0                Extinct
# 2536         ǁKu ǁ'e                   0                Extinct
# 2537          ǁKx'au                   0                Extinct
# 2538          ǁXegwi                   0                Extinct
#
#                                          Wikipedia Page
# 0     [https://en.wikipedia.org/wiki/Extreme_Souther...
# 1     [https://en.wikipedia.org/wiki/Sicilian_language]
# ...
