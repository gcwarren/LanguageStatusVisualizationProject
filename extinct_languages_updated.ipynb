# %%
import pandas as pd 
import numpy as np
import requests
from tqdm import tqdm

data = pd.read_csv('Extinct languages - DATA SUMMARY.csv')

# %%
data
# Out:
#      Name in English  Number of speakers Degree of endangerment
# 0      South Italian             7500000             Vulnerable
# 1           Sicilian             5000000             Vulnerable
# 2          Low Saxon             4800000             Vulnerable
# 3         Belarusian             4000000             Vulnerable
# 4            Lombard             3500000  Definitely endangered
# ...              ...                 ...                    ...
# 2534          |'Auni                   0                Extinct
# 2535            |Xam                   0                Extinct
# 2536         ǁKu ǁ'e                   0                Extinct
# 2537          ǁKx'au                   0                Extinct
# 2538          ǁXegwi                   0                Extinct
#
# [2539 rows x 3 columns]

# %%
wikipedia_links = pd.read_csv('extinct_languages_with_links.csv')
# import requests
# import re
# languages = data['Name in English'].to_list()
# wikipedia_links = []


# for language in tqdm(languages):
#     url = f"https://en.wikipedia.org/wiki/{language.replace(' ', '_')}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         match = re.search(r'<link rel="canonical" href="([^"]+)"', response.text)
#         if match:
#             wikipedia_links.append(match.group(1))
#         else:
#             wikipedia_links.append(None)
#     else:
#         wikipedia_links.append(None)

# wikipedia_links
# data.loc[0:2539, 'Wikipedia URL'] = wikipedia_links
# data.to_csv('extinct_languages_links.csv', index=False)

# %%
data = wikipedia_links

# %%
missed_indices = data[data['Wikipedia URL'].isnull()].index
missed_indices

# for row in data.iterrows():
#     if row[1]['Wikipedia URL'] is  None:
#         print(row[1]['Name in English'], row[0])
# Out:
# Int64Index([ 399,  433,  442,  451,  556,  593, 1008, 1177, 1677, 1978, 2095,
#             2415, 2432, 2441, 2476, 2534, 2536, 2537],
#            dtype='int64')

# %%
# Yiddish (Israel), 6
data.at[6, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yiddish'
# Limburgian-Ripuarian 8
data.at[8, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limburgish_language'
# Quechua of Southern Bolivia 9
data.at[9, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Southern_Quechua'
# Kurux (India) 16
data.at[16, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
# Quechua of Cuzco 28
data.at[28, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cusco_Quechua'
# Eastern Slovak 29
data.at[29, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Slovak_language'
# K'iche' (Guatemala) 37
data.at[37, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/K%27iche%27_language'
# Quechua of Ayacucho 38
data.at[38, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ayacucho_Quechua'
# Tamaceq 42
data.at[42, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamasheq_language'
# Q'eqchi' (Guatemala) 47
data.at[47, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Q%27eqchi%27_language'
# Quechua of Ancash and Huánuco 54
data.at[54, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ancash_Quechua'
# Mam (Guatemala) 66
data.at[66, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mam_language'
# Kaqchikel (Guatemala) 71
data.at[71, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaqchikel_language'
# Judezmo (Israel) 77
data.at[77, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Spanish'
# Mapuche (Chile) 81
data.at[81, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mapuche_language'
# Buryat (Trans-Baikal) 92
data.at[92, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buryat_language'
# Moroccan Judeo-Arabic (Israel) 96
data.at[96, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Moroccan_Arabic'
# Quichua (Cotopaxi, Tungurahua and Chimborazo) 99
data.at[99, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quichua_language'
# Phula (China) 106
data.at[106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phula_language'
# Khorasani Turk 122
data.at[122, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khorasani_Turkic_language'
# Western Armenian (Middle East) 125
data.at[125, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Western_Armenian'
# Gagauz (Bessarabia) 129
data.at[129, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gagauz_language'
# Ngäbere (Panama) 134
data.at[134, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ng%C3%A4bere_language'
# Asturian-Leonese 140
data.at[140, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Astur-Leonese_languages'
# Tamzabit 144
data.at[144, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight_language'
# Q'aanjob'al 147
data.at[147, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Q%27anjob%27al_language'
# Tamahaq (Algeria) 158
data.at[158, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamasheq_language'
# Crimean Tatar (Crimea) 167
data.at[167, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Crimean_Tatar_language'
# Dagur (Nonni) 168
data.at[168, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Daur_language'
# Mapuche (Argentina) 171
data.at[171, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mapuche_language'
# Miskito (Nicaragua) 173
data.at[173, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miskito_language'
# Quechua of Northern Bolivia 175
data.at[175, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Quechua'
# Garífuna (Honduras) 177
data.at[177, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Garifuna_language'
# Embera (Colombia) 178
data.at[178, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ember%C3%A1_languages'
# Yimchungru 183
data.at[183, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yimchungru_language'
# Nogay (Caucasus) 184
data.at[184, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nogai_language'
# Quichua (Cañar and Azuay) 186
data.at[186, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quichua_language'
# Ixil (Guatemala) 193
data.at[193, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ixil_language'
# Quechua of Santiago del Estero 200
data.at[200, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Santiago_del_Estero_Quechua'
# Tai Neua 209
data.at[209, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tai_Nuea_language'
# Bhadravahi 210
data.at[210, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bhadravahi_language'
# Kurux (Bangladesh) 213
data.at[213, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
# Ashaninka (Peru) 216
data.at[216, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ashaninka_language'
# Kuna (Panama) 218
data.at[218, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuna_language'
# Chuj (Guatemala) 225
data.at[225, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chuj_language'
# Buryat (Cis-Baikal) 234
data.at[234, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buryat_language'
# Buryat (Manchuria) 235
data.at[235, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buryat_language'
# Cuona Menba 236
data.at[236, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Menba_language'
# Quichua (Imbabura) 241
data.at[241, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Imbabura_Quechua'
# Southern Altay 243
data.at[243, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Altay_language'
# Võro-Seto 246
data.at[246, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/V%C3%B5ro_language'
# Western Armenian (Turkey) 248
data.at[248, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Western_Armenian'
# Bhumji 253
data.at[253, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bhumij_language'
# Cosung (China) 254
data.at[254, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cosung_language'
# Cosung (Viet Nam) 255
data.at[255, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cosung_language'
# Baheng (China) 256
data.at[256, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baheng_language'
# Quichua (Loja) 258
data.at[258, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Loja_Quechua'
# Kheza 267
data.at[267, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kheza_language'
# Jola-Kassa 268
data.at[268, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kassa_language'
# Satār 269
data.at[269, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Satar_language'
# Guaraní Boliviano 270
data.at[270, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bolivian_Guarani'
# Quechua of Cajatambo, Pasco and northern Junín 277
data.at[277, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cajatambo_Quechua'
# Quichua (Napo) 278
data.at[278, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Napo_Quechua'
# Akatek (Guatemala) 291
data.at[291, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Akatek_language'
# Shuar chicham 297
data.at[297, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shuar_language'
# Sikuani 300
data.at[300, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sikuani_language'
# Jakaltek (Guatemala) 301
data.at[301, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jakaltek_language'
# Sirmaudi 310
data.at[310, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sirmauri_language'
# Judeo-Berber (Israel) 318
data.at[318, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Berber_language'
# Mok (Myanmar, Thailand) 323
data.at[323, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mok_language'
# Quechua of Cajamarca 327
data.at[327, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cajamarca_Quechua'
# Quichua (Pastaza) 328
data.at[328, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pastaza_Quechua'
# Tialo 331
data.at[331, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tialo_language'
# Tidikelt 332
data.at[332, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tidikelt_language'
# Vojvodina Rusyn 335
data.at[335, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rusyn_language'
# Wuse 336
data.at[336, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wuse_language'
# Mzieme 340
data.at[340, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mzieme_language'
# Kurux (Nepal) 343
data.at[343, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurukh_language'
# Mancagne 350
data.at[350, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mancagne_language'
# Csángó Hungarian 353
data.at[353, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cs%C3%A1ng%C3%B3_language'
# Minhe Monguor 355
data.at[355, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Monguor_language'
# Miskito (Honduras) 356
data.at[356, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miskito_language'
# Olonetsian 357
data.at[357, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Olonetsian_language'
# Tamazight (Beni Iznassen) 360
data.at[360, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight_language'
# Embera (Panama) 371
data.at[371, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ember%C3%A1_languages'
# Ediamat 372
data.at[372, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ediamat_language'
# Zapotec of the Valleys, middle northwest 384
data.at[384, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zapotec_languages'
# Cho-ca-nga-ca-kha 388
data.at[388, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cho-ca-nga-ca-kha_language'
# Crimean Tatar (Dobruja) 389
data.at[389, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Crimean_Tatar_language'
# Griko (Salento) 391
data.at[391, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Griko_dialect'
# Kaiowá Guarani 392
data.at[392, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaiow%C3%A1_language'
# Karelian (Karelia) 393
data.at[393, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karelian_language'
# Khoirao 394
data.at[394, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khoirao_language'
# Manchad 395
data.at[395, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manchad_language'
# Pemon (Venezuela) 398
data.at[398, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pemon_language'
# Tacenwit 399
data.at[399, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tacenwit_language'
# Pochuri 417
data.at[417, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pochuri_language'
# Tamahaq (Libya) 418
data.at[418, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamasheq_language'
# Pangvali 422
data.at[422, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pangvali_language'
# Gurdu-Mbaaru 432
data.at[432, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gurdu-Mbaaru_language'
# Ha-lung Tibetan 433
data.at[433, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Halung_language'
# Laemae 437
data.at[437, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laemae_language'
# Lavua 438
data.at[438, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lavua_language'
# Macushi (Brazil) 439
data.at[439, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Macushi_language'
# Nyoe 442
data.at[442, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nyoe_language'
# O'odham (Akimel) 443
data.at[443, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tohono_O%27odham_language'
# O'odham (Tohono) 444
data.at[444, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tohono_O%27odham_language'
# Tayurayt 451
data.at[451, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tayurayt_language'
# Aruaco 453
data.at[453, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aruaco_language'
# Garífuna (Belize) 458
data.at[458, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Garifuna_language'
# Uhunduni 463
data.at[463, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Uhunduni_language'
# Q'eqchi' (Belize) 472
data.at[472, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Q%27eqchi%27_language'
# Badiaranke 475
data.at[475, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Badiaranke_language'
# Tobada' 485
data.at[485, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tobada%27_language'
# Yurt Tatar 486
data.at[486, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yurt_Tatar_language'
# Yaqui (Mexico) 487
data.at[487, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yaqui_language'
# Ch'orti' (Guatemala) 488
data.at[488, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ch%27orti%27_language'
# Kari'ña (Venezuela) 495
data.at[495, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kari%27%C3%B1a_language'
# Piaroa (Venezuela) 497
data.at[497, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piaroa_language'
# Waunana (Colombia) 499
data.at[499, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waunana_language'
# Central Alaskan Yupik (2) 502
data.at[502, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Alaskan_Yup%27ik_language'
# Central Alaskan Yupik (Nuniak Island) 503
data.at[503, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Alaskan_Yup%27ik_language'
# Cherokee (Oklahoma) 517
data.at[517, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cherokee_language'
# Huitoto (Colombia, Peru) 519
data.at[519, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Huitoto_language'
# Hulaula (Israel) 520
data.at[520, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hulaul%C3%A1_language'
# Karelian (Tver) 522
data.at[522, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karelian_language'
# Kurripako (Colombia, Venezuela) 525
data.at[525, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurripako_language'
# Lamgang 527
data.at[527, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lamgang_language'
# Muot 530
data.at[530, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Muot_language'
# Ñandeva Guarani 532
data.at[532, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/%C3%91andeva_language'
# Northern Khanty 535
data.at[535, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Khanty_language'
# Orang Hulu 538
data.at[538, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Orang_Hulu_language'
# Tamazight (Tunisia) 544
data.at[544, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight_language'
# Trukhmen 548
data.at[548, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Turkmen_language'
# Awakatek (Guatemala) 552
data.at[552, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Awakatek_language'
# Choctaw (Louisiana) 553
data.at[553, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Choctaw_language'
# Choctaw (Mississipi) 554
data.at[554, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Choctaw_language'
# Choctaw (Oklahoma) 555
data.at[555, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Choctaw_language'
# Taruang 557
data.at[557, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taruang_language'
# Phula (Viet Nam) 562
data.at[562, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phula_language'
# Dol-po 563
data.at[563, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dolpo_language'
# Motuo Menba 566
data.at[566, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Motuo_language'
# Panamahka 567
data.at[567, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Panamahka_language'
# Mopán (Belize) 569
data.at[569, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mopan_language'
# Ts'amay 572
data.at[572, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ts%27amay_language'
# Micmac (Massachusetts) 580
data.at[580, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mi%27kmaq_language'
# Austral dialects 582
data.at[582, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Australian_Aboriginal_languages'
# Mbya Guarani (Paraguay) 590
data.at[590, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mby%C3%A1_Guaran%C3%AD_language'
# Quichua (Salasaca) 593
data.at[593, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Salasaca_Quechua'
# Mam (Mexico) 601
data.at[601, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mam_language'
# Macushi (Guyana) 603
data.at[603, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Macushi_language'
# Awa Cuaiquer 606
data.at[606, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Awa_language'
# Lishana Deni (Israel) 607
data.at[607, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishana_Deni'
# Mebengokre 610
data.at[610, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mebengokre_language'
# Quechua of Peruvian Amazonia 612
data.at[612, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Peruvian_Amazonian_Quechua'
# Choyi 616
data.at[616, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Choyi_language'
# Guichong 618
data.at[618, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guichong_language'
# Tucano (Brazil) 626
data.at[626, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tucano_language'
# Wapishana (Guyana) 627
data.at[627, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wapishana_language'
# Waunana (Panama) 633
data.at[633, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waunana_language'
# Micmac (Canada) 636
data.at[636, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mi%27kmaq_language'
# Rio Grande Keresan 639
data.at[639, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Keresan_languages'
# Kumāle 647
data.at[647, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kum%C4%81le_language'
# Chiquitano (Bolivia) 650
data.at[650, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chiquitano_language'
# Ampibabo Lauje 660
data.at[660, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ampibabo_language'
# Cashinahua (Brazil) 661
data.at[661, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cashinahua_language'
# Mbya Guarani (Brazil) 663
data.at[663, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mby%C3%A1_Guaran%C3%AD_language'
# Nheengatu / Yeral (Brazil) 666
data.at[666, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nheengatu_language'
# Quechua of San Martín 668
data.at[668, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/San_Mart%C3%ADn_Quechua'
# Yanomami (Brazil) 673
data.at[673, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yanomami_language'
# Baníwa do Içana 677
data.at[677, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ban%C3%ADwa_language'
# Akawaio (Guyana, Venezuela) 678
data.at[678, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Akawaio_language'
# Bribri (Costa Rica) 683
data.at[683, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bribri_language'
# Kwatay 685
data.at[685, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kwatay_language'
# Baheng (Viet Nam) 686
data.at[686, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baheng_language'
# Sak (Bangladesh) 689
data.at[689, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sak_language'
# Anung (China) 697
data.at[697, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Anung_language'
# Cubeo (Colombia) 705
data.at[705, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cubeo_language'
# Dagur (Hailar) 706
data.at[706, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Daur_language'
# Mo'ang (China) 727
data.at[727, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mo%27ang_language'
# Mo'ang (Viet Nam) 728
data.at[728, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mo%27ang_language'
# Moroccan Judeo-Arabic (Morocco) 730
data.at[730, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moroccan_Jewish_Arabic'
# Patamona (Guyana) 733
data.at[733, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Patamona_language'
# Pume 735
data.at[735, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pume_language'
# Udi (Azerbaijan) 738
data.at[738, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Udi_language'
# Yecuana (Venezuela) 739
data.at[739, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yekuana_language'
# Romani (Colombia) 742
data.at[742, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Romani_language'
# Saryg Yugur 750
data.at[750, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Saryg_Yugur_language'
# Piapoko 754
data.at[754, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piapoco_language'
# Eastern Montagnais 765
data.at[765, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Innu_language'
# Acoma-Laguna 768
data.at[768, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Keresan_languages'
# Cashinahua (Peru) 774
data.at[774, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cashinahua_language'
# Evenki (Manchuria) 776
data.at[776, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Evenki_language'
# Gazhuo 777
data.at[777, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gazhuo_language'
# Kari'ña (Guyana, Suriname) 779
data.at[779, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kari%27%C3%B1a_language'
# Lishan Didan (Israel) 780
data.at[780, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishan_Didan'
# Shingsaba 784
data.at[784, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shingsaba_language'
# Sinkiang Dagur 785
data.at[785, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Daur_language'
# Wapishana (Brazil) 788
data.at[788, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wapishana_language'
# Yanomám 790
data.at[790, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yanomami_language'
# Yanomami (Venezuela) 791
data.at[791, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yanomami_language'
# Zenaga (Mauritania) 793
data.at[793, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zenaga_language'
# Bharmauri 795
data.at[795, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bharmauri_language'
# Khang Quang Lam 797
data.at[797, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khang_language'
# Mixtec of the Puebla-Oaxaca border 800
data.at[800, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mixtec_language'
# Nupri 801
data.at[801, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nupri_language'
# Utsat 804
data.at[804, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Utsat_language'
# Garífuna (Guatemala) 808
data.at[808, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Garifuna_language'
# Nachiring 809
data.at[809, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nachiring_language'
# Anung (Myanmar) 812
data.at[812, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Anung_language'
# Sak (Myanmar) 815
data.at[815, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sak_language'
# Northwestern Ojibwe 818
data.at[818, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ojibwe_language'
# Teribe (Panama) 823
data.at[823, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Teribe_language'
# Juhur (Caucasus) 831
data.at[831, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Juhuri_language'
# Baleasang 833
data.at[833, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baleasang_language'
# Brokshat 838
data.at[838, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Brokshat_language'
# Eastern Khanty 842
data.at[842, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Eastern_Khanty_language'
# Limirong Tibetan 854
data.at[854, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Limirong_language'
# Lishanid Noshan (Israel) 855
data.at[855, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishanid_Noshan'
# Mbya Guarani (Argentina, Uruguay) 857
data.at[857, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mby%C3%A1_Guaran%C3%AD_language'
# Mohawk (Akwesasne, St. Regis) 858
data.at[858, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mohawk_language'
# Pukur 864
data.at[864, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pukur_language'
# Shira Yugur 868
data.at[868, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shira_Yugur_language'
# Takahanyilang 869
data.at[869, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Takahanyilang_language'
# Western Montagnais 875
data.at[875, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Innu_language'
# Waiwai (Brazil) 876
data.at[876, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waiwai_language'
# Kohi 889
data.at[889, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kohi_language'
# Bribri (Panama) 896
data.at[896, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bribri_language'
# Culina (Peru) 900
data.at[900, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Culina_language'
# Laomian (China) 903
data.at[903, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laomian_language'
# Laomian (Myanmar) 904
data.at[904, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laomian_language'
# Martuwangka 906
data.at[906, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Martuthunira_language'
# Mayoruna (Peru) 907
data.at[907, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mayoruna_language'
# Roshorvi 911
data.at[911, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Roshorvi_language'
# Urak Lawoi (Malaysia) 914
data.at[914, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Urak_Lawoi_language'
# Urak Lawoi (Thailand) 915
data.at[915, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Urak_Lawoi_language'
# Mopán (Guatemala) 918
data.at[918, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mopan_language'
# Mang (China) 924
data.at[924, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mang_language'
# Mang (Viet Nam) 925
data.at[925, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mang_language'
# Blackfoot (Canada) 927
data.at[927, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Blackfoot_language'
# North Alaskan Inupiaq (Kotzebue Sound) 934
data.at[934, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# North Alaskan Inupiaq (North Slope) 935
data.at[935, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Seward Peninsula Inupiaq (King Island) 936
data.at[936, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Seward Peninsula Inupiaq (Little Diomede Island) 937
data.at[937, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Seward Peninsula Inupiaq (Norton Sound) 938
data.at[938, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Zaozou 941
data.at[941, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zaozou_language'
# Ngäbere (Costa Rica) 942
data.at[942, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ng%C3%A4bere_language'
# Athpahariya 949
data.at[949, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Athpahariya_language'
# Ava-Guaraní 950
data.at[950, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ava_Guaran%C3%AD_language'
# Bayso 951
data.at[951, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bayso_language'
# Culina (Brazil) 957
data.at[957, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Culina_language'
# Duguza 959
data.at[959, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Duguza_language'
# Galibi Marworno 960
data.at[960, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Galibi_language'
# Gats'ama - Ganjule - Harro 961
data.at[961, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gats%27ama_language'
# Griko (Calabria) 964
data.at[964, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Griko_dialect'
# Kari'ña (French Guyana) 969
data.at[969, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kari%27%C3%B1a_language'
# Nheengatu / Yeral (Venezuela) 986
data.at[986, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nheengatu_language'
# Nyishangba 988
data.at[988, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nyishangba_language'
# Ottawa (Walpole Island) 989
data.at[989, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ottawa_language'
# Shoshoni (Idaho) 995
data.at[995, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shoshoni_language'
# Shoshoni (Nevada) 996
data.at[996, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shoshoni_language'
# Shoshoni (Wyoming) 997
data.at[997, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shoshoni_language'
# Tamazight (Arzew) 999
data.at[999, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight_language'
# Tinan 1002
data.at[1002, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tinan_language'
# Waotededo 1008
data.at[1008, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waotededo_language'
# Hupda (Brazil) 1012
data.at[1012, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hup_language'
# Nila (Seram Island) 1022
data.at[1022, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nila_language'
# Chuj (Mexico) 1024
data.at[1024, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chuj_language'
# Lokono (Guyana) 1027
data.at[1027, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lokono_language'
# Cheyenne (Montana) 1032
data.at[1032, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cheyenne_language'
# Quechua of Yauyos 1034
data.at[1034, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yauyos_Quechua'
# Tamazight (Ait Rouadi) 1040
data.at[1040, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamazight_language'
# Southern Tiwa (Isleta Pueblo) 1044
data.at[1044, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Southern_Tiwa_language'
# Southern Tiwa (Sandia Pueblo) 1045
data.at[1045, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Southern_Tiwa_language'
# Tewa (Arizona) 1046
data.at[1046, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tewa_language'
# Tewa (New Mexico) 1047
data.at[1047, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tewa_language'
# Hupda (Colombia) 1056
data.at[1056, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hup_language'
# K'emant 1060
data.at[1060, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/K%27emant_language'
# Karelian (Tikhvin) 1063
data.at[1063, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karelian_language'
# Mayoruna (Brazil) 1067
data.at[1067, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mayoruna_language'
# Mescalero-Chiricahua Apache (New Mexico) 1068
data.at[1068, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mescalero-Chiricahua_language'
# Numao Bunu 1069
data.at[1069, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Numao_Bunu_language'
# Palenque Creole 1071
data.at[1071, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Palenquero'
# Pyuma 1073
data.at[1073, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pyuma_language'
# Wayana (Suriname) 1078
data.at[1078, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wayana_language'
# Kanela Rankokamekra 1088
data.at[1088, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kanela_language'
# Kurripako (Brazil) 1090
data.at[1090, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurripako_language'
# Triw 1091
data.at[1091, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Triw_language'
# Chɨlɨng 1094
data.at[1094, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chilung_language'
# Zapotec of the Valleys north 1095
data.at[1095, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zapotec_languages'
# Palikur (Brazil) 1097
data.at[1097, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Palikur_language'
# Sanenyo 1098
data.at[1098, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sanenyo_language'
# Xinka 1100
data.at[1100, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xinka_language'
# Kāgate 1102
data.at[1102, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/K%C4%81gate_language'
# Manjui 1115
data.at[1115, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manjui_language'
# Te'un (Seram Island) 1116
data.at[1116, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Te%27un_language'
# White Gelao (China) 1119
data.at[1119, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Dakkang 1120
data.at[1120, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dakkang_language'
# Northern Algonquin 1121
data.at[1121, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Algonquin_language'
# Akawaio (Brazil) 1122
data.at[1122, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Akawaio_language'
# Trio (Brazil) 1124
data.at[1124, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Trio_language'
# Waimirí-Atroarí 1128
data.at[1128, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waimiri-Atroari_language'
# Fagauvea (Northern) 1130
data.at[1130, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Fagauvea_language'
# Fagauvea (Southern) 1131
data.at[1131, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Fagauvea_language'
# Arapaho (Wyoming) 1147
data.at[1147, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arapaho_language'
# Blackfoot (United States of America) 1149
data.at[1149, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Blackfoot_language'
# Bong'om 1152
data.at[1152, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bong%27om_language'
# Central Siberian Yupik (St. Lawrence Island) 1154
data.at[1154, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Siberian_Yupik_language'
# Cherokee (North Carolina) 1156
data.at[1156, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cherokee_language'
# Cocama-Cocamilla (Peru) 1157
data.at[1157, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cocama_language'
# Dakpa 1159
data.at[1159, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dakpa_language'
# Danaw 1161
data.at[1161, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Danaw_language'
# Gambiri 1166
data.at[1166, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gambiri_language'
# Inkhokvari 1177
data.at[1177, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inkhokvari_language'
# Kaande 1181
data.at[1181, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaande_language'
# Lokono (Suriname) 1192
data.at[1192, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lokono_language'
# Manchurian Ölöt 1194
data.at[1194, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manchu_language'
# Thavung (Laos) 1213
data.at[1213, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Thavung_language'
# Trio (Suriname) 1217
data.at[1217, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Trio_language'
# Zenaga (Western Sahara) 1223
data.at[1223, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zenaga_language'
# |Gui 1224
data.at[1224, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gui_language'
# Buglé 1226
data.at[1226, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bugl%C3%A9_language'
# Ka'apór 1227
data.at[1227, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ka%27apor_language'
# Machineri (Brazil) 1234
data.at[1234, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Machineri_language'
# Kuna (Colombia) 1247
data.at[1247, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuna_language'
# Ashaninka (Brazil) 1257
data.at[1257, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ashaninka_language'
# Ottawa (Canada) 1258
data.at[1258, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ottawa_language'
# Chorote Iyojwa'ja 1260
data.at[1260, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chorote_language'
# Piaroa (Colombia) 1267
data.at[1267, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piaroa_language'
# Tuyuca (Brazil) 1270
data.at[1270, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tuyuca_language'
# Ese eja 1273
data.at[1273, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ese_Eja_language'
# Waiwai (Suriname) 1278
data.at[1278, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waiwai_language'
# Nambiquara do Sul 1283
data.at[1283, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nambikwara_language'
# A'ingae / Cofan (Ecuador) 1286
data.at[1286, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/A%27ingae_language'
# Mok (China) 1293
data.at[1293, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mok_language'
# Piratapuya (Brazil) 1296
data.at[1296, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piratapuyo_language'
# Nivkh (Sakhalin) 1298
data.at[1298, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nivkh_language'
# Krikati 1299
data.at[1299, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Krikati_language'
# Wanano / Kotiria (Brazil) 1304
data.at[1304, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wanano_language'
# Eastern Ojibwe 1306
data.at[1306, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ojibwe_language'
# Yuhup (Brazil) 1308
data.at[1308, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yuhup_language'
# Desano (Brazil) 1314
data.at[1314, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Desano_language'
# Northern Selkup 1325
data.at[1325, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Selkup_language'
# Piratapuya (Colombia) 1328
data.at[1328, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piratapuyo_language'
# Siona / Secoya (Ecuador) 1329
data.at[1329, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Siona_language'
# Yaminahua (Brazil) 1332
data.at[1332, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yaminahua_language'
# Chatong 1337
data.at[1337, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chatong_language'
# Norfolk-Pitcairn (Norfolk) 1338
data.at[1338, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Norfolk_language'
# Yuhup (Colombia) 1350
data.at[1350, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yuhup_language'
# Narpa 1355
data.at[1355, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Narpa_language'
# Akatek (Mexico) 1356
data.at[1356, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Akatek_language'
# Yaqui (United States of America) 1363
data.at[1363, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yaqui_language'
# Jakaltek (Mexico) 1366
data.at[1366, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jakaltek_language'
# Ganan 1380
data.at[1380, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ganan_language'
# Kensiw (Thailand) 1382
data.at[1382, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kensiw_language'
# Laha (Lao Cai) 1387
data.at[1387, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laha_language'
# Laha (Son La) 1388
data.at[1388, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laha_language'
# Laxudumau 1390
data.at[1390, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laxudumau_language'
# Maliseet-Passamaquoddy 1392
data.at[1392, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maliseet_language'
# Palikur (French Guyana) 1397
data.at[1397, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Palikur_language'
# Pemon (Brazil) 1398
data.at[1398, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pemon_language'
# Quechua of Chachapoyas 1399
data.at[1399, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chachapoyas_Quechua'
# Siona / Secoya (Colombia) 1402
data.at[1402, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Siona_language'
# Tawahka 1407
data.at[1407, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tawahka_language'
# Thavung (Thailand) 1408
data.at[1408, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Thavung_language'
# Toratán 1410
data.at[1410, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Torat%C3%A1n_language'
# Tunisian Judeo-Arabic (Tunisia) 1411
data.at[1411, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tunisian_Jewish_Arabic'
# Ute (Colorado, Ute Mountain) 1413
data.at[1413, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ute_language'
# Warekena (Venezuela) 1415
data.at[1415, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Warekena_language'
# Pukobyê 1417
data.at[1417, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pukoby%C3%AA_language'
# Swoeng 1418
data.at[1418, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Swoeng_language'
# Gavião do Pará 1420
data.at[1420, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gavi%C3%A3o_language'
# Ninam (Brazil) 1422
data.at[1422, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ninam_language'
# Zoró 1423
data.at[1423, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zor%C3%B3_language'
# Sanema (Brazil) 1424
data.at[1424, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sanema_language'
# Ottawa (Michigan) 1426
data.at[1426, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ottawa_language'
# Kanela Apaniekra 1427
data.at[1427, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kanela_language'
# Koasati (Louisiana) 1431
data.at[1431, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koasati_language'
# Koasati (Texas) 1432
data.at[1432, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koasati_language'
# Siona  Secoya (Peru) 1436
data.at[1436, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Siona_language'
# Gavião de Rondônia 1440
data.at[1440, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gavi%C3%A3o_language'
# Yecuana (Brazil) 1443
data.at[1443, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yekuana_language'
# Alabugat Tatar 1444
data.at[1444, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Alabugat_Tatar_language'
# Katukina do Acre 1449
data.at[1449, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Katukina_language'
# Barasana (Colombia) 1451
data.at[1451, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Barasana_language'
# Cheyenne (Oklahoma) 1454
data.at[1454, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cheyenne_language'
# Cobiana 1456
data.at[1456, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cobiana_language'
# Dagur (Amur) 1457
data.at[1457, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dagur_language'
# Gagauz (Maritime) 1460
data.at[1460, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gagauz_language'
# Kickapoo (Kansas) 1467
data.at[1467, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kickapoo_language'
# Kickapoo (Oklahoma) 1468
data.at[1468, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kickapoo_language'
# Kickapoo (Texas) 1469
data.at[1469, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kickapoo_language'
# Lamongse 1472
data.at[1472, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lamongse_language'
# Northern Paiute (Nevada) 1474
data.at[1474, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Paiute_language'
# Pupeo 1475
data.at[1475, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pupeo_language'
# Red Gelao (China) 1477
data.at[1477, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Talondo 1480
data.at[1480, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Talondo_language'
# Yaminahua (Bolivia, Peru) 1481
data.at[1481, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yaminahua_language'
# Sanema (Venezuela) 1483
data.at[1483, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sanema_language'
# A'ingae / Cofan (Colombia) 1488
data.at[1488, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/A%27ingae_language'
# Mra 1497
data.at[1497, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mra_language'
# Myky 1498
data.at[1498, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Myky_language'
# Barām 1504
data.at[1504, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bar%C4%81m_language'
# Kaningara 1511
data.at[1511, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaningara_language'
# Nambiquara do Norte 1514
data.at[1514, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nambikwara_language'
# Green Gelao (China) 1531
data.at[1531, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Green Gelao (Viet Nam) 1532
data.at[1532, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Kwansu 1540
data.at[1540, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kwansu_language'
# Northern Paiute (Oregon) 1547
data.at[1547, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Paiute_language'
# Tlingit (United States of America) 1555
data.at[1555, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tlingit_language'
# Tuahka 1558
data.at[1558, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tawahka_language'
# Ute (Utah) 1559
data.at[1559, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ute_language'
# Yawarana 1564
data.at[1564, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yawarana_language'
# Wayana (Brazil) 1568
data.at[1568, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wayana_language'
# Maniwaki Algonquin 1571
data.at[1571, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Algonquin_language'
# Cocopa (Arizona) 1573
data.at[1573, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cocopa_language'
# Bosilewa 1579
data.at[1579, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bosilewa_language'
# Caquinte Campa 1580
data.at[1580, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Caquinte_language'
# Gwich'in (Canada) 1581
data.at[1581, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gwich%27in_language'
# Laji 1585
data.at[1585, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laji_language'
# Winnebago (Nebraska) 1594
data.at[1594, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Winnebago_language'
# Winnebago (Wisconsin) 1595
data.at[1595, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Winnebago_language'
# North Alaskan Inupiaq (Canada) 1598
data.at[1598, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Waiwai (Guyana) 1599
data.at[1599, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waiwai_language'
# K'iche' (Mexico) 1602
data.at[1602, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/K%27iche%27_language'
# Garuwahi 1604
data.at[1604, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Garuwahi_language'
# Danisi 1608
data.at[1608, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Danisi_language'
# Pwaamèi 1612
data.at[1612, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pwaam%C3%A8i_language'
# Cocopa (Mexico) 1615
data.at[1615, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cocopa_language'
# Korúbo 1616
data.at[1616, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kor%C3%BAbo_language'
# Antakirinya 1618
data.at[1618, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Antakirinya_language'
# Central Siberian Yupik (Chukotka) 1624
data.at[1624, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Siberian_Yupik_language'
# Chawte 1625
data.at[1625, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chawte_language'
# Che Wong 1626
data.at[1626, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Che_Wong_language'
# Numbani 1651
data.at[1651, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Numbami_language'
# Ongamo 1653
data.at[1653, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ongamo_language'
# Sauk-Fox 1658
data.at[1658, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sauk_language'
# |Xaise 1664
data.at[1664, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xaise_language'
# Tipai (Mexico) 1667
data.at[1667, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tipai_language'
# Uru-eu-au-au 1668
data.at[1668, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Uru-eu-wau-wau_language'
# Jarawára 1672
data.at[1672, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jarawara_language'
# Keder 1673
data.at[1673, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Keder_language'
# Central Ojibwe 1676
data.at[1676, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ojibwe_language'
# Kuurinji 1677
data.at[1677, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurinji_language'
# Zapotec of the Southern mountains, northwest lowlands 1680
data.at[1680, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zapotec_languages'
# Onjab 1685
data.at[1685, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Onjab_language'
# Aleut (Eastern) 1691
data.at[1691, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aleut_language'
# Aleut (Western) 1692
data.at[1692, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aleut_language'
# Assiniboine (United States of America) 1695
data.at[1695, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Assiniboine_language'
# Cubeo (Brazil) 1699
data.at[1699, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cubeo_language'
# Gwich'in (United States of America) 1700
data.at[1700, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gwich%27in_language'
# Katxuyana-Xikuyána 1702
data.at[1702, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Katxuyana_language'
# Malmariv 1705
data.at[1705, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Malmariv_language'
# Ocaina (Peru) 1707
data.at[1707, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ocaina_language'
# Southern Ayta 1710
data.at[1710, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ayta_language'
# Tundra Yukagir 1711
data.at[1711, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yukaghir_language'
# Kickapoo (Mexico) 1718
data.at[1718, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kickapoo_language'
# Dengalu 1721
data.at[1721, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dengalu_language'
# Machineri (Bolivia) 1724
data.at[1724, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Machineri_language'
# ǂHoa 1726
data.at[1726, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/%C7%82Hoa_language'
# Handuri 1727
data.at[1727, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Handuri_language'
# Ocaina (Colombia) 1733
data.at[1733, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ocaina_language'
# Asurini do Xingu 1735
data.at[1735, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Asurini_language'
# Nahukwa 1736
data.at[1736, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahukwa_language'
# Ili Turk 1741
data.at[1741, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ili_Turk_language'
# Polonomombauk 1744
data.at[1744, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Polonomombauk_language'
# Banawá Yafi 1755
data.at[1755, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Banaw%C3%A1_language'
# Bara (Colombia) 1756
data.at[1756, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bara_language'
# Mohave (Arizona) 1776
data.at[1776, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mohave_language'
# Mohave (California) 1777
data.at[1777, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mohave_language'
# Nemadi 1782
data.at[1782, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nemadi_language'
# Ninam (Venezuela) 1783
data.at[1783, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ninam_language'
# Omagua (Peru) 1784
data.at[1784, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Omagua_language'
# Seneca (United States of America) 1793
data.at[1793, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Seneca_language'
# Tai Nora 1799
data.at[1799, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tai_Nora_language'
# Tai Rong 1800
data.at[1800, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tai_Rong_language'
# Tariana (Brazil) 1802
data.at[1802, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tariana_language'
# Ute (Colorado, Southern Ute) 1804
data.at[1804, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ute_language'
# O'odham (Mexico) 1810
data.at[1810, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tohono_O%27odham_language'
# Patamona (Brazil) 1820
data.at[1820, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Patamona_language'
# Assiniboine (Canada) 1826
data.at[1826, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Assiniboine_language'
# Dorro 1827
data.at[1827, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dorro_language'
# Siriano (Brazil) 1841
data.at[1841, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Siriano_language'
# East Cape Yupik 1847
data.at[1847, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yupik_languages'
# Kari'ña (Brazil) 1856
data.at[1856, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kari%27%C3%B1a_language'
# Ixil (Mexico) 1860
data.at[1860, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ixil_language'
# Carapana (Brazil) 1862
data.at[1862, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Carapana_language'
# Carapana (Colombia) 1866
data.at[1866, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Carapana_language'
# Gurrgoni 1868
data.at[1868, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gurrgoni_language'
# Ngangikurunggurr 1871
data.at[1871, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngandi_language'
# Tapayuna 1877
data.at[1877, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tapayuna_language'
# Teribe (Costa Rica) 1880
data.at[1880, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Teribe_language'
# Tlingit (Canada) 1885
data.at[1885, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tlingit_language'
# Upper Tanana (United States of America) 1886
data.at[1886, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Upper_Tanana_language'
# Chiquitano (Brazil) 1895
data.at[1895, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chiquitano_language'
# Forest Yukagir 1896
data.at[1896, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yukaghir_language'
# Iduh (Lao PDR) 1898
data.at[1898, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Iduh_language'
# Karaim (Lithuania) 1899
data.at[1899, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karaim_language'
# Kasong 1900
data.at[1900, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kasong_language'
# Moraori 1906
data.at[1906, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moraori_language'
# Norfolk-Pitcairn (Pitcairn) 1909
data.at[1909, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Norfolk_language'
# Potawatomi (Kansas) 1915
data.at[1915, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Potawatomi_language'
# Potawatomi (Michigan) 1916
data.at[1916, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Potawatomi_language'
# Potawatomi (Oklahoma) 1917
data.at[1917, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Potawatomi_language'
# Potawatomi (Wisconsin) 1918
data.at[1918, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Potawatomi_language'
# Sentilese 1922
data.at[1922, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sentinelese_language'
# Mono (Western) 1941
data.at[1941, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mono_language'
# Tipai (United States of America) 1943
data.at[1943, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tipai_language'
# Chulym Turk 1948
data.at[1948, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chulym_language'
# Kaqchikel (Mexico) 1950
data.at[1950, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaqchikel_language'
# Quechua of Pacaraos 1952
data.at[1952, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pacaraos_Quechua'
# Barasana (Brazil) 1954
data.at[1954, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Barasana_language'
# Macuna (Brazil) 1956
data.at[1956, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Macuna_language'
# Cambap 1965
data.at[1965, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cambap_language'
# Chintaw 1967
data.at[1967, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chintaw_language'
# Comox/Sliammon 1968
data.at[1968, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Comox_language'
# Kawucha 1972
data.at[1972, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kawucha_language'
# Mono (Eastern) 1974
data.at[1974, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mono_language'
# Punan Batu 1976
data.at[1976, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Punan_Batu_language'
# Sia Pedee 1978
data.at[1978, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sia_Pedee_language'
# Wik Ngencherr 1982
data.at[1982, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wik_Ngathan_language'
# Sakurabiat 1995
data.at[1995, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sakurabiat_language'
# Bara (Brazil) 2008
data.at[2008, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bara_language'
# Barzani Jewish Neo-Aramaic (Israel) 2011
data.at[2011, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Barzani_Jewish_Neo-Aramaic'
# Chung (Cambodia) 2014
data.at[2014, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chung_language'
# Kulina Páno 2026
data.at[2026, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kulina_language'
# Red Gelao (Viet Nam) 2040
data.at[2040, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Warekena (Brazil) 2047
data.at[2047, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Warekena_language'
# White Gelao (Viet Nam) 2048
data.at[2048, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Uruak 2050
data.at[2050, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Uruak_language'
# Ava-Canoeiro 2053
data.at[2053, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ava-Canoeiro_language'
# Ainu (Hokkaido) 2055
data.at[2055, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ainu_language'
# Han (United States of America) 2065
data.at[2065, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Han_language'
# Ngaatjatjara 2069
data.at[2069, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngaatjatjara_language'
# Kinikinau 2074
data.at[2074, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kinikinau_language'
# Arho 2077
data.at[2077, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arho_language'
# Bangsa 2080
data.at[2080, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ch%27orti%27_language'
# Ch'orti' (Honduras) 2081
data.at[2081, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ch%27orti%27_language'
# Chung (Thailand) 2082
data.at[2082, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chung_language'
# Khövsgöl Uryangkhay 2095
data.at[2095, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kh%C3%B6vsg%C3%B6l_language'
# Manchu (Amur) 2103
data.at[2103, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manchu_language'
# Manchu (Nonni) 2104
data.at[2104, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Manchu_language'
# Marrisyefin 2106
data.at[2106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Marrisyefin_language'
# Matanvat 2108
data.at[2108, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Matanvat_language'
# Mawayana (Brazil) 2110
data.at[2110, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mawayana_language'
# Munsee (Canada) 2111
data.at[2111, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Munsee_language'
# Naati 2112
data.at[2112, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Naati_language'
# Northern Paiute (Idaho) 2115
data.at[2115, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Paiute_language'
# Oneida (Wisconsin) 2117
data.at[2117, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Oneida_language'
# Onondaga (New York) 2118
data.at[2118, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Onondaga_language'
# Puari 2122
data.at[2122, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Puari_language'
# Taap 2127
data.at[2127, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taap_language'
# Arára Shawãdáwa 2137
data.at[2137, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ar%C3%A1ra_language'
# N|uu 2151
data.at[2151, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/N%C7%8F%C7%8F_language'
# Karaim (Western Ukraine) 2159
data.at[2159, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karaim_language'
# Aleut (Western, Commander Islands) 2165
data.at[2165, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aleut_language'
# Aqaw Gelao 2166
data.at[2166, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gelao_language'
# Aveteian 2167
data.at[2167, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Selkup_language'
# Central Selkup 2168
data.at[2168, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Selkup_language'
# Cocama-Cocamilla (Brazil) 2169
data.at[2169, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cocama_language'
# Great andamanese 2172
data.at[2172, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Great_Andamanese_languages'
# Iduh (Viet Nam) 2175
data.at[2175, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Iduh_language'
# Nivat 2191
data.at[2191, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nivat_language'
# Niviar 2192
data.at[2192, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nivat_language'
# Sorsorian 2197
data.at[2197, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sorsorian_language'
# Southern Selkup 2198
data.at[2198, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Southern_Selkup_language'
# Umbrul 2200
data.at[2200, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Umbrul_language'
# Guranalum 2207
data.at[2207, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guranalum_language'
# Awakatek (Mexico) 2218
data.at[2218, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Awakatek_language'
# Mabiri 2228
data.at[2228, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mabiri_language'
# Mescalero-Chiricahua Apache (Oklahoma) 2229
data.at[2229, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mescalero_language'
# Tuscarora (United States of America) 2235
data.at[2235, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tuscarora_language'
# Andoa (Peru) 2237
data.at[2237, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Andoa_language'
# Aurê-Aurá 2239
data.at[2239, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aur%C3%AA_language'
# Baré (Brazil) 2240
data.at[2240, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bar%C3%A9_language'
# Cayuvava 2241
data.at[2241, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cayuvava_language'
# Guarasu 2244
data.at[2244, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guarasu_language'
# Kujubim 2246
data.at[2246, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kujubim_language'
# Oneida (New York) 2252
data.at[2252, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Oneida_language'
# Poyanawa 2253
data.at[2253, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Poyanawa_language'
# Salamãy 2255
data.at[2255, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Salam%C3%A3y_language'
# Tharkarri 2258
data.at[2258, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tharkarri_language'
# Vacacocha 2259
data.at[2259, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Vacacocha_language'
# Xipáya 2261
data.at[2261, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xip%C3%A1ya_language'
# Diahói 2267
data.at[2267, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Diah%C3%B3i_language'
# Kaixána 2268
data.at[2268, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaix%C3%A1na_language'
# Wintu-Nomlaki 2279
data.at[2279, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wintu_language'
# Yarawi 2281
data.at[2281, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yarawi_language'
# !Gan!ne 2282
data.at[2282, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gan%21ne_language'
# Ainu (Kuril) 2285
data.at[2285, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ainu_language'
# Ainu (Sakhalin) 2286
data.at[2286, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ainu_language'
# Andoa (Ecuador) 2290
data.at[2290, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Andoa_language'
# Arapaho (Oklahoma) 2295
data.at[2295, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arapaho_language'
# Arapáso 2296
data.at[2296, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arap%C3%A1so_language'
# Baga Kalem 2305
data.at[2305, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baga_Kalem_language'
# Barzani Jewish Neo-Aramaic (Iraq) 2308
data.at[2308, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Barzani_Jewish_Neo-Aramaic'
# Birgid 2314
data.at[2314, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Birgid_language'
# Cape Khoekhoe 2317
data.at[2317, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khoekhoe_language'
# Cappadocian Greek (Turkey) 2318
data.at[2318, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cappadocian_Greek'
# Cayuga (Oklahoma) 2320
data.at[2320, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cayuga_language'
# Central Kalapuyan 2322
data.at[2322, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kalapuya_language'
# Deti 2331
data.at[2331, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Deti_language'
# Dungidjau 2338
data.at[2338, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dungidjau_language'
# Elmolo 2345
data.at[2345, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Elmolo_language'
# Eotile 2346
data.at[2346, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Eotile_language'
# Garífuna (Nicaragua) 2350
data.at[2350, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Garifuna_language'
# Getmata 2352
data.at[2352, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Getmata_language'
# Gyasumdo 2359
data.at[2359, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gyasumdo_language'
# Hpun 2364
data.at[2364, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hpun_language'
# Huitoto (Brazil) 2365
data.at[2365, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Huitoto_language'
# Huron-Wyandot (United States of America) 2367
data.at[2367, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wyandot_language'
# Island Chumash 2371
data.at[2371, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chumashan_languages'
# Judeo-Berber (Morocco) 2373
data.at[2373, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Berber_language'
# Kamas Turk 2375
data.at[2375, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kamas_language'
# Karaim (Crimea) 2378
data.at[2378, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karaim_language'
# Karelian (Valday) 2380
data.at[2380, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karelian_language'
# Kede 2385
data.at[2385, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kede_language'
# Khaccaḍ Bhoṭe 2390
data.at[2390, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khacca%C1%B9_Bho%E1%B9%ADe_language'
# Krenjê 2397
data.at[2397, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Krenak_language'
# Krevin 2398
data.at[2398, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Krevin_language'
# Kyakala 2404
data.at[2404, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kyakala_language'
# Langthang Tibetan 2406
data.at[2406, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Langthang_language'
# Li-Ngbee 2408
data.at[2408, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Li-Ngbee_language'
# Liliali 2409
data.at[2409, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Liliali_language'
# Lishan Didan (Iran) 2411
data.at[2411, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishan_Didan'
# Lishana Deni (Iraq) 2412
data.at[2412, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishanid_Noshan'
# Lishanid Noshan (Iraq) 2413
data.at[2413, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishanid_Noshan'
# Loke Tibetan 2414
data.at[2414, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Loke_language'
# Lorkoti 2415
data.at[2415, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lorkoti_language'
# Marrgu 2422
data.at[2422, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Marrgu_language'
# Miraña (Brazil) 2428
data.at[2428, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mira%C3%B1a_language'
# Mirití Tapuia 2429
data.at[2429, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mirit%C3%AD_Tapuya_language'
# Mlahso (Syria) 2430
data.at[2430, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mlahso_language'
# Mlahso (Turkey) 2431
data.at[2431, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mlahso_language'
# Mo-peng 2432
data.at[2432, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mo-peng_language'
# Múra 2438
data.at[2438, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/M%C3%BAra_language'
# Napore 2441
data.at[2441, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Napore_language'
# Nila (Nila Island) 2446
data.at[2446, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nila_language'
# Nukiní 2451
data.at[2451, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nukini_language'
# Omagua (Brazil) 2458
data.at[2458, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Omagua_language'
# Ongkor Solon 2460
data.at[2460, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ongkor_Solon_language'
# Opon-Carare 2461
data.at[2461, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Opon_language'
# Phalok 2467
data.at[2467, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phalok_language'
# Qwarenya 2476
data.at[2476, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Qwarenya_language'
# Sanhaja of Srair 2478
data.at[2478, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sanhaja_language'
# Seward Peninsula Inupiaq (Big Diomede Island) 2484
data.at[2484, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Inupiat_language'
# Siraiya 2486
data.at[2486, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Siraiya_language'
# Taokas 2498
data.at[2498, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taokas_language'
# Te'un (Te'un Island) 2499
data.at[2499, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Te%27un_language'
# Ubykh (Caucasus) 2509
data.at[2509, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ubykh_language'
# Ubykh (Turkey) 2510
data.at[2510, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ubykh_language'
# Yurutí (Brazil) 2532
data.at[2532, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yurut%C3%AD_language'
# |'Auni 2534
data.at[2534, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Auni_language'
# |Xam 2535
data.at[2535, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xam_language'
# ǁKu ǁ'e 2536
data.at[2536, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ku%27%C7%81e_language'
# ǁKx'au 2537
data.at[2537, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kx%27au_language'

# %%
data = data.dropna()

# %%
# for index in missed_indices:
#     if data.loc[index, 'Wikipedia URL'] is not None and requests.get(data.loc[index, 'Wikipedia URL']).status_code != 200:
#         print('Language:', data.loc[index, 'Name in English'], 'Index:', index, 'URL:', data.loc[index, 'Wikipedia URL'])

# %%
data.at[96, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Moroccan_Arabic'
data.at[236, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Takpa_language'
data.at[258, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
data.at[268, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kasa_language#:~:text=Kasa%2C%20or%20J%C3%B3ola%2DKaasa%20(,of%20Senegal%20and%20neighboring%20Gambia.&text=Niger%E2%80%93Congo%3F&text=Dialects%20are%20Ayun%2C%20Bliss%20(Niomoun,referred%20to%20as%20a%2Dluf.'
data.at[277, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cajatambo#:~:text=The%20variety%20of%20Quechua%20spoken,with%20the%20neighboring%20Huamalies%20Quechua.'
data.at[278, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
data.at[353, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cs%C3%A1ng%C3%B3s'
data.at[388, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chochangachakha_language#:~:text=The%20Chocha%20Ngacha%20language%20or,Kurichu%20Valley%20of%20Lhuntse%20and'
data.at[399, 'Wikipedia URL'] = None
data.at[433, 'Wikipedia URL'] = None
data.at[442, 'Wikipedia URL'] = None
data.at[451, 'Wikipedia URL'] = None
data.at[556, 'Wikipedia URL'] = None
data.at[567, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sumo_languages'
data.at[593, 'Wikipedia URL'] = None
data.at[612, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quechuan_languages'
data.at[677, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baniwa#:~:text=Baniwa%20(also%20known%20with%20local,Maipurean%20(Arawak)%20language%20family.'
data.at[730, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Moroccan_Arabic#:~:text=Widely%20used%20in%20the%20Jewish,from%20Spain%20after%20the%201492'
data.at[961, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kachama-Ganjule_language'
data.at[1008, 'Wikipedia URL'] = None
data.at[1094, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chulung_language'
data.at[1177, 'Wikipedia URL'] = None
data.at[1226, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buglere#:~:text=Buglere%2C%20also%20known%20as%20Bugle,spoken%20by%20the%20Bokota%20people.'
data.at[1407, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sumo_languages'
data.at[1411, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Judeo-Tunisian_Arabic#:~:text=Judeo%2DTunisian%20Arabic%2C%20also%20known,passive%20knowledge%20of%20the%20language.'
data.at[1558, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miskito_language'
data.at[1625, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chothe_language'
data.at[1626, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cheq_Wong_language'
data.at[1677, 'Wikipedia URL'] = None
data.at[1978, 'Wikipedia URL'] = None
data.at[2095, 'Wikipedia URL'] = None
data.at[2151, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/N%C7%81ng_language'
data.at[2282, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gan_Chinese#:~:text=Gan%2C%20Gann%20or%20Kan%20is,Hubei%2C%20Anhui%2C%20and%20Fujian.'
data.at[2296, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arapaho_language'
data.at[2305, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baga_language'
data.at[2364, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hpon_language'
data.at[2390, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_Tibetan'
data.at[2398, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Krevinian_dialect#:~:text=Krevinian%2C%20or%20Krevin%20(Latvian%3A,city%20of%20Bauske%2C%20in%20Courland.&text=The%20Krevinian%20dialect%20left%20loanwords,such%20as%20kurika%20'
data.at[2408, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngbee_language'
data.at[2415, 'Wikipedia URL'] = None
data.at[2429, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miriti_language'
data.at[2432, 'Wikipedia URL'] = None
data.at[2438, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mura_language'
data.at[2441, 'Wikipedia URL'] = None
data.at[2476, 'Wikipedia URL'] = None
data.at[2478, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sanhaja_de_Srair_language#:~:text=Senhaja%20de%20Srair%20(%22Senhaja%20of,speaking%20area%20in%20eastern%20Rif.&text=Despite%20its%20speech%20area%2C%20the,the%20Atlas%20branch%20of%20Berber.'
data.at[2534, 'Wikipedia URL'] = None
data.at[2536, 'Wikipedia URL'] = None
data.at[2537, 'Wikipedia URL'] = None

# %%
data
# Out:
#      Name in English  Number of speakers Degree of endangerment  \
# 0      South Italian           7500000.0             Vulnerable
# 1           Sicilian           5000000.0             Vulnerable
# 2          Low Saxon           4800000.0             Vulnerable
# 3         Belarusian           4000000.0             Vulnerable
# 4            Lombard           3500000.0  Definitely endangered
# ...              ...                 ...                    ...
# 2535            |Xam                 0.0                Extinct
# 2536         ǁKu ǁ'e                 0.0                Extinct
# 2537          ǁKx'au                 0.0                Extinct
# 2538          ǁXegwi                 0.0                Extinct
# 556              NaN                 NaN                    NaN
#
#                                           Wikipedia URL
# 0     https://en.wikipedia.org/wiki/Neapolitan_language
# 1                https://en.wikipedia.org/wiki/Sicilian
# ...

# %%
data['Wikipedia URL'].value_counts(dropna=False)
# Out:
# None                                                  18
# https://en.wikipedia.org/wiki/Tlapanec_language        8
# https://en.wikipedia.org/wiki/Tec%C3%B3atl_Mazatec     8
# https://en.wikipedia.org/wiki/Gelao_language           7
# https://en.wikipedia.org/wiki/Inupiat_language         7
#                                                       ..
# https://en.wikipedia.org/wiki/Shira_Yugur_language     1
# https://en.wikipedia.org/wiki/Sherdukpen_people        1
# https://en.wikipedia.org/wiki/Savi                     1
# https://en.wikipedia.org/wiki/Rotuman                  1
# https://en.wikipedia.org/wiki/%C7%81Xegwi_language     1
# Name: Wikipedia URL, Length: 2266, dtype: int64

# %%
data.to_csv('extinct_languages_with_links.csv', index=False)

# %% [markdown]
# ## Checking for disambiguation pages

# %%
data = data.dropna()

# %%
data.loc[96, 'Wikipedia URL'] = data.loc[96, 'Wikipedia URL']

# %%
data.at[96, 'Wikipedia URL'] = data.at[96, 'Wikipedia URL']

# %%
import requests 
from bs4 import BeautifulSoup
from tqdm import tqdm

for index, row in tqdm(data.iterrows()):
    url = row['Wikipedia URL']
    response = requests.get(url)
    if response.status_code != 200:
        # print('Status NOT 200 - Language:', row['Name in English'], 'URL:', row['Wikipedia URL'])
        pass
    else: 
        # check link with title Help:Category 
        soup = BeautifulSoup(response.text, 'html.parser')

        # Get all links with title = Help:Category
        relevant_links = soup.find_all('a', title='Help:Category')
        if relevant_links[0].text == 'Category': 
            # print('Appending lang to URL - Language:', row['Name in English'], 'URL:', row['Wikipedia URL'])
            data.at[index, 'Wikipedia URL'] = data.at[index, 'Wikipedia URL'] + '_language'
# Out:
# 589it [02:48,  3.49it/s]

# %%
data.to_csv('extinct_languages_with_links.csv', index=False)
# Out:
#   Name in English  Number of speakers Degree of endangerment  \
# 0   South Italian           7500000.0             Vulnerable
# 1        Sicilian           5000000.0             Vulnerable
# 2       Low Saxon           4800000.0             Vulnerable
# 3      Belarusian           4000000.0             Vulnerable
# 4         Lombard           3500000.0  Definitely endangered
#
#                                        Wikipedia URL
# 0  https://en.wikipedia.org/wiki/Neapolitan_language
# 1    https://en.wikipedia.org/wiki/Sicilian_language
# 2            https://en.wikipedia.org/wiki/Low_Saxon
# 3  https://en.wikipedia.org/wiki/Belarusian_language
# 4              https://en.wikipedia.org/wiki/Lombard
