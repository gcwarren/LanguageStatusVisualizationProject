# %%
import pandas as pd 

extinct_langs = pd.read_csv('Extinct languages - DATA SUMMARY.csv')

wiki_langs = pd.read_csv('wiki_languages_most_recent.csv', index_col=0)

region_langs = pd.read_csv('languages_by_region.csv')

# %%
extinct_langs.shape, wiki_langs.shape, region_langs.shape
# Out:
# ((2539, 3), (1330, 8), (210, 6))

# %%
extinct_langs.head()
# Out:
#   Name in English  Number of speakers Degree of endangerment
# 0   South Italian             7500000             Vulnerable
# 1        Sicilian             5000000             Vulnerable
# 2       Low Saxon             4800000             Vulnerable
# 3      Belarusian             4000000             Vulnerable
# 4         Lombard             3500000  Definitely endangered

# %%
from nltk.metrics.distance import edit_distance

# %%
wiki_langs[:20]
# Out:
#                               lang  \
# 0                          Durango
# 1   Azoyu_Me%E2%80%99phaa_language
# 2                          Mizoram
# 3                  Herero_language
# 4                     Azad_Kashmir
# 5          Country_of_Cura%C3%A7ao
# 6                            Afade
# 7                   Chewa_language
# 8                 Tunceli_Province
# 9                 Ilocano_language
# 10            Pirah%C3%A3_language
# 11                        Thailand
# 12               Asturian_language
# 13              East_Nusa_Tenggara
# 14                           Tonga
# 15                   Avar_language
# 16                     Shan_people
# 17                        Mindanao
# 18                 Buryat_language
# 19             Lithuanian_language
#
#                                                family  \
# 0                                                 NaN
# 1          ['Oto-Manguean', 'Tlapanecan', 'Tlapanec']
# 2                                                 NaN
# 3   ['Niger–Congo', '?\n', 'Atlantic–Congo', 'Volt...
# 4                                                 NaN
# 5                                                 NaN
# 6   ['Afro-Asiatic', 'Chadic', 'Biu–Mandara', 'Kot...
# 7   ['Niger–Congo', '?\n', 'Atlantic–Congo', 'Volt...
# 8                                                 NaN
# 9   ['Austronesian', 'Malayo-Polynesian', 'Philipp...
# 10                                 ['Mura', 'Pirahã']
# 11                                                NaN
# 12  ['Indo-European', 'Italic', 'Latino-Faliscan',...
# 13                                                NaN
# 14                                                NaN
# 15      ['Northeast Caucasian', 'Avar–Andic', 'Avar']
# 16                                                NaN
# 17                                                NaN
# 18  ['Mongolic', '\nCentral Mongolic', 'Buryat–', ...
# 19  ['Indo-European', 'Balto-Slavic', 'Baltic', 'E...
#
#                                              dialects  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   ['Himba', 'Kuvale', 'Zemba', ' (Thimba, ', 'Ot...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                               ['Western Asturian']
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                ['Samogitian', ', ', 'Aukštaitian']
#
#                                              iso3code  \
# 0                                                 NaN
# 1   Variously:tcf – Malinaltepec (east)tpc – Azoyú...
# 2                                                 NaN
# 3                                         her  Herero
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 aal
# 7                                                 nya
# 8                                                 NaN
# 9                                                 ilo
# 10                                                myp
# 11                                                NaN
# 12                                                ast
# 13                                                NaN
# 14                                                NaN
# 15                  Either:ava – Avaricoav – Old Avar
# 16                                                NaN
# 17                                                NaN
# 18  bua – inclusive code BuriatIndividual codes:bx...
# 19  Either:lit – Modern Lithuanianolt – Old Lithua...
#
#                                              speakers  \
# 0                                                 NaN
# 1                            150,000 (2020 census)[1]
# 2                                                 NaN
# 3                              250,000 (2015–2018)[1]
# 4                                                 NaN
# 5                                                 NaN
# 6   5,000 in Cameroon (2004)[1]unknown number in N...
# 7                                 7 million (2007)[1]
# 8                                                 NaN
# 9   6,370,000 (2005)[1]2 million L2 speakers (2000...
# 10                                  250–380 (2009)[1]
# 11                                                NaN
# 12  Around 1/3 of Asturians[1] (2000)62% of Asturi...
# 13                                                NaN
# 14                                                NaN
# 15                                1,200,000 (2021)[1]
# 16                                                NaN
# 17                                                NaN
# 18                             440,000 (2017–2020)[1]
# 19                              3.0 million (2012)[1]
#
#                                               regions  \
# 0                                                 NaN
# 1                                   Guerrero, Morelos
# 2                                     Northeast India
# 3   Kunene, Omaheke Region and Otjozondjupa Region...
# 4                                                 NaN
# 5                                                 NaN
# 6   Far North Province, Cameroon; Borno State, Nig...
# 7                                    Southeast Africa
# 8                                                 NaN
# 9   Northern Luzon, many parts of Central Luzon an...
# 10                                        Maici River
# 11                                                NaN
# 12                                           Asturias
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                             Baltic
#
#                      off_lang              rec_min_lang
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                      Malawi  \n Mozambique\n Zambia\n
# 8                         NaN                       NaN
# 9                 La Union[4]               Philippines
# 10                        NaN                       NaN
# 11                        NaN                       NaN
# 12                        NaN      Asturias[3]  (Spain)
# 13                        NaN                       NaN
# 14                        NaN                       NaN
# 15        Russia\n Dagestan\n                       NaN
# 16                        NaN                       NaN
# 17                        NaN                       NaN
# 18          Buryatia (Russia)                       NaN
# 19   Lithuania European Union                    Poland

# %%
row = wiki_langs.iloc[2]
region = row['regions'].lower()

id_min = region_langs['Country/Region'].apply(lambda x: edit_distance(x.lower(), region)).idxmin()

region_langs.iloc[id_min]
# Out:
# Country/Region                  North Macedonia
# Official Language    ['Macedonian', 'Albanian']
# Regional Language                          ['']
# Minority Language                          ['']
# National Language                          ['']
# Widely Spoken                              ['']
# Name: 137, dtype: object

# %%
region_langs.head()
# Out:
#   Country/Region             Official Language  \
# 0       Abkhazia         ['Abkhaz', 'Russian']
# 1    Afghanistan  ['Persian (Dari)', 'Pashto']
# 2        Albania                  ['Albanian']
# 3        Algeria          ['Arabic', 'Berber']
# 4        Andorra                   ['Catalan']
#
#                                    Regional Language  \
# 0                                               ['']
# 1  ['Uzbek', 'Turkmen', 'Pashayi', 'Nuristani', '...
# 2                                               ['']
# 3                                               ['']
# 4                                               ['']
#
#                       Minority Language             National Language  \
# 0                          ['Georgian']                    ['Abkhaz']
# 1                                  ['']  ['Persian (Dari)', 'Pashto']
# 2  ['Greek', 'Macedonian', 'Aromanian']                          ['']
# 3                                  ['']          ['Arabic', 'Berber']
# 4   ['Spanish', 'French', 'Portuguese']                          ['']
#
#         Widely Spoken
# 0                ['']
# 1  ['Persian (Dari)']
# 2         ['Italian']
# 3          ['French']
# 4                ['']
