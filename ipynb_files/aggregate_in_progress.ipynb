# %%
import pandas as pd 
import requests
import unicodedata
from tqdm import tqdm
from bs4 import BeautifulSoup
# Out:
# /var/folders/gl/l6pb7jfx42l02zc9950kh3fh0000gn/T/ipykernel_5589/632010323.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
wiki_data = pd.read_csv('wiki_languages_most_recent.csv')
# wiki_data

# %%
unesco_data = pd.read_csv('extinct_languages_links.csv')
# unesco_data

# %%
glottolog_data = pd.read_csv('languages_and_dialects_geo.csv')
glottolog_data
# Out:
#       glottocode        name isocodes     level  macroarea  latitude  \
# 0       3adt1234  3Ad-Tekles      NaN   dialect     Africa       NaN
# 1       aala1237      Aalawa      NaN   dialect  Papunesia       NaN
# 2       aant1238  Aantantara      NaN   dialect  Papunesia       NaN
# 3       aari1239        Aari      aiw  language     Africa   5.95034
# 4       aari1240      Aariya      aay  language    Eurasia       NaN
# ...          ...         ...      ...       ...        ...       ...
# 22106   zuwa1238     Zuwadza      NaN   dialect  Papunesia       NaN
# 22107   zwal1238       Zwall      NaN   dialect     Africa       NaN
# 22108   zyph1238       Zyphe      zyp  language    Eurasia  22.52400
# 22109   zyud1238     Zyuzdin      NaN   dialect    Eurasia       NaN
# 22110   huaa1249        ǂHua      NaN   dialect     Africa       NaN
#
#        longitude
# 0            NaN
# 1            NaN
# 2            NaN
# 3        36.5721
# 4            NaN
# ...          ...
# 22106        NaN
# 22107        NaN
# 22108    93.2640
# 22109        NaN
# 22110        NaN
#
# [22111 rows x 7 columns]

# %%
# Glottolog is very specific in naming dialects and other varieties, so iso codes will likely be more navigable

wiki_lang = wiki_data['lang'].to_list()
unesco_lang = unesco_data['Name in English'].to_list()
wiki_unesco_lang = pd.DataFrame({'Agg': list(set(wiki_lang) & set(unesco_lang))})

glottolog_lang = pd.DataFrame({'Glotto lang': glottolog_data['name']})
print(len(set(set(glottolog_lang['Glotto lang']).intersection(set(wiki_unesco_lang['Agg'])))))
# Out:
# 9

# %% [markdown]
# ## Merging

# %%
geodata = pd.read_csv('languages_and_dialects_geo.csv')

langs = pd.read_csv('Extinct languages - DATA SUMMARY.csv')

# %%
geodata.head()
# Out:
#   glottocode        name isocodes     level  macroarea  latitude  longitude
# 0   3adt1234  3Ad-Tekles      NaN   dialect     Africa       NaN        NaN
# 1   aala1237      Aalawa      NaN   dialect  Papunesia       NaN        NaN
# 2   aant1238  Aantantara      NaN   dialect  Papunesia       NaN        NaN
# 3   aari1239        Aari      aiw  language     Africa   5.95034    36.5721
# 4   aari1240      Aariya      aay  language    Eurasia       NaN        NaN

# %%
langs.head()
# Out:
#   Name in English  Number of speakers Degree of endangerment
# 0   South Italian             7500000             Vulnerable
# 1        Sicilian             5000000             Vulnerable
# 2       Low Saxon             4800000             Vulnerable
# 3      Belarusian             4000000             Vulnerable
# 4         Lombard             3500000  Definitely endangered

# %%
len(set(geodata['name'].str.lower().values).intersection(set(langs['Name in English'].str.lower().values)))
# Out:
# 1315

# %%
geodata.head()
# Out:
#   glottocode        name isocodes     level  macroarea  latitude  longitude  \
# 0   3adt1234  3Ad-Tekles      NaN   dialect     Africa       NaN        NaN
# 1   aala1237      Aalawa      NaN   dialect  Papunesia       NaN        NaN
# 2   aant1238  Aantantara      NaN   dialect  Papunesia       NaN        NaN
# 3   aari1239        Aari      aiw  language     Africa   5.95034    36.5721
# 4   aari1240      Aariya      aay  language    Eurasia       NaN        NaN
#
#   name_normalized
# 0      3ad-tekles
# 1          aalawa
# 2      aantantara
# 3            aari
# 4          aariya

# %%
geodata['name_normalized'] = geodata['name'].str.lower()
langs['name_normalized'] = langs['Name in English'].str.lower()

merged = pd.merge(geodata, langs, left_on='name_normalized', right_on='name_normalized', how='inner')

# what does how = 'inner' do in pd.merge()


merged_drop_na = merged.dropna(subset=['isocodes'])
merged_mass = pd.merge(merged_drop_na, wiki_data, left_on = 'isocodes', right_on = 'iso3code', how = 'inner')

# %%
merged_mass
# Out:
#     glottocode          name isocodes     level      macroarea  latitude  \
# 0     aasa1238         Aasax      aas  language         Africa  -4.00679
# 1     abaz1241         Abaza      abq  language        Eurasia  44.25000
# 2     achu1247      Achumawi      acv  language  North America  41.09790
# 3     akka1237  Akkala Saami      sia  language        Eurasia  67.86250
# 4     akum1238          Akum      aku  language         Africa   6.85716
# ..         ...           ...      ...       ...            ...       ...
# 106   warl1254      Warlpiri      wbp  language      Australia -20.10080
# 107   wels1247         Welsh      cym  language        Eurasia  52.00000
# 108   west2392  Western Mari      mrj  language        Eurasia  56.22000
# 109   yuch1247         Yuchi      yuc  language  North America  35.75000
# 110   zuni1245          Zuni      zun  language  North America  35.00560
#
#      longitude name_normalized Name in English  Number of speakers  \
# 0     36.86480           aasax           Aasax                   0
# 1     42.00000           abaza           Abaza               31000
# 2   -121.19100        achumawi        Achumawi                  10
# 3     32.40460    akkala saami    Akkala Saami                   0
# 4      9.96261            akum            Akum                 600
# ..         ...             ...             ...                 ...
# 106  131.05000        warlpiri        Warlpiri                3000
# 107   -4.00000           welsh           Welsh              750000
# 108   46.56900    western mari    Western Mari               36822
# 109  -86.75000           yuchi           Yuchi                   5
# 110 -108.78200            zuni            Zuni                9000
#
#     Degree of endangerment  Unnamed: 0               lang  \
# 0                  Extinct          57         Aas%C3%A1x
# 1    Definitely endangered          80     Abaza_language
# 2    Critically endangered         739  Achumawi_language
# 3                  Extinct         157   Akkala_S%C3%A1mi
# 4    Critically endangered          91      Akum_language
# ..                     ...         ...                ...
# 106             Vulnerable         287  Warlpiri_language
# 107             Vulnerable         942     Welsh_language
# 108    Severely endangered        1220          Hill_Mari
# 109  Critically endangered         228     Yuchi_language
# 110             Vulnerable         824      Zuni_language
#
#                                                 family  \
# 0    ['Afro-Asiatic', 'Cushitic', 'Rift', '?', 'Eas...
# 1           ['Northwest Caucasian', 'Abazgi', 'Abaza']
# 2    ['Hokan', '\xa0?\n', 'Shasta', '–Palaihnihan\x...
# 3    ['Uralic', 'Sámi', 'Eastern', 'Mainland', 'Akk...
# 4    ['Niger–Congo', '?\n', 'Atlantic–Congo', 'Benu...
# ..                                                 ...
# 106  ['Pama–Nyungan', 'Ngumpin–Yapa', 'Ngarrkic', '...
# 107  ['Indo-European', 'Celtic', 'Insular Celtic', ...
# 108    ['Uralic', 'Mari', 'Western Mari', 'Hill Mari']
# 109                               ['Language isolate']
# 110                               ['Language isolate']
#
#                                               dialects iso3code  \
# 0                                                  NaN      aas
# 1                                                  NaN      abq
# 2                                                  NaN      acv
# 3                                                  NaN      sia
# 4                                                  NaN      aku
# ..                                                 ...      ...
# 106  ['Warlpiri', 'Ngaliya', 'Walmala', 'Ngardilpa'...      wbp
# 107  ['Cofi', 'Gwyndodeg', 'Powyseg', 'Dyfedeg', 'G...      cym
# 108                                                NaN      mrj
# 109                                                NaN      yuc
# 110                                                NaN      zun
#
#                                               speakers  \
# 0                                                  NaN
# 1                                49,800 (2010–2014)[1]
# 2                                                  NaN
# 3                                                  NaN
# 4    1,400 in Cameroon (2002)[1]few in Nigeria (no ...
# ..                                                 ...
# 106                             2,624 (2021 census)[1]
# 107  \nWales: 538,300 (17.8% of the population of W...
# 108                                   30,000 (2012)[1]
# 109                0[2] (2021)12 L2 speakers (2016)[1]
# 110                                    9,620 (2015)[1]
#
#                                                regions  \
# 0                                             Tanzania
# 1                                  Karachay-Cherkessia
# 2                                                  NaN
# 3                             Southwest Kola Peninsula
# 4                                         Taraba State
# ..                                                 ...
# 106                      Northern Territory, Australia
# 107  United Kingdom (Wales, England), Argentina (Ch...
# 108  Mari El (Gornomariysky, Yurinsky, Kilemarsky d...
# 109                              East central Oklahoma
# 110                                 Western New Mexico
#
#                         off_lang                 rec_min_lang
# 0                            NaN                          NaN
# 1     Russia Karachay-Cherkessia                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 106                          NaN                          NaN
# 107                        Wales  Argentina (Chubut Province)
# 108               Russia Mari El                          NaN
# 109                          NaN                          NaN
# 110                          NaN                          NaN
#
# [111 rows x 20 columns]

# %%
merged['level'].value_counts()
# Out:
# level
# language    1167
# dialect      153
# Name: count, dtype: int64

# %%
merged.to_csv('merged.csv', index=False)
