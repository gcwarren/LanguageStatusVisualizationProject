# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv('Extinct languages - DATA SUMMARY.csv')

# %%
data['Degree of endangerment'].value_counts()
# Out:
# Degree of endangerment
# Definitely endangered    635
# Vulnerable               611
# Critically endangered    544
# Severely endangered      505
# Extinct                  244
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

colors = sns.color_palette('viridis', len(data['Degree of endangerment'].value_counts()))

fig, ax = plt.subplots()
# ax.bar(data['Degree of endangerment'].value_counts().index, data['Degree of endangerment'].value_counts(), color = colors)
plt.barh(data['Degree of endangerment'].value_counts().index, data['Degree of endangerment'].value_counts(), color = colors)
plt.show()
