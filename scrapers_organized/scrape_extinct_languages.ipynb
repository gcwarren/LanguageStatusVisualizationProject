# %%
import pandas as pd 
import requests
import unicodedata
from tqdm import tqdm
from bs4 import BeautifulSoup
# Out:
# /var/folders/gl/l6pb7jfx42l02zc9950kh3fh0000gn/T/ipykernel_1929/632010323.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('../extinct_languages_with_links.csv')
# data['Name in English'].to_list()

# %%
# '4    Lombard',
data.at[4, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lombard_language'
#  '5    Romani',
data.at[5, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Romani_language'
#  '7    Gondi',
data.at[7, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gondi_language'
#  '11    Aymara',
data.at[11, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aymara_language'
#  '17    Tamajeq',
data.at[17, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tamajeq_language'
#  '18    Tulu',
data.at[18, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tulu_language'
#  '19    Kangdi',
data.at[19, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kangdi_language'
#  '32    Talysh',
data.at[32, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Talysh_language'
#  '33    Kui',
data.at[33, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kui_language'
#  '35    Bodo',
data.at[35, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bodo_language'
#  '40    Mon',
data.at[40, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mon_language'
#  '43    Avar',
data.at[43, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Avar_language'
#  '48    Picard',
data.at[48, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Picard_language'
#  '55    Walloon',
data.at[55, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Walloon_language'
#  '61    Brahui',
data.at[61, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Brahui_language'
#  '65    Magar',
data.at[65, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Magar_language'
#  '67    Udmurt',
data.at[67, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Udmurt_language'
#  '72    Karbi',
data.at[72, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karbi_language'
#  '76    Ho',
data.at[76, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ho_language'
#  '78    Lalo',
data.at[78, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lalo_language'
#  '82    Central Náhuatl',
data.at[82, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Central_N%C3%A1huatl'
#  '103    Bade',
data.at[103, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bade_language'
#  '105    Gascon',
data.at[105, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gascon_language'
#  '106       Phula (China)',
data.at[106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phula_language'
#  '107    Sora',
data.at[107, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sora_language'
#  '109    Ao',
data.at[109, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ao_language'
#  '115    Maiya',
data.at[115, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maiya_language'
#  '116    Komi',
data.at[116, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Komi_language'
#  '117     Alpine Provençal',
data.at[117, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Alpine_Proven%C3%A7al'
#  '131    Adi',
data.at[131, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Adi_language'
#  '139    Lak',
data.at[139, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lak_language'
#  '140    Asturian-Leonese',
data.at[140, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Asturian-Leonese_language'
#  '150    Laz',
data.at[150, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laz_language'
#  '151    Tabasaran',
data.at[151, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tabasaran_language'
#  '159    Konda',
data.at[159, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Konda_language'
#  '165    Simi',
data.at[165, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Simi_language'
#  '172    Mehri',
data.at[172, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mehri_language'
#  '174    Ordos',
data.at[174, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ordos_language'
#  '176    Suba',
data.at[176, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Suba_language'
#  '192    Sangtam',
data.at[192, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sangtam_language'
#  '195    Yem',
data.at[195, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yem_language'
#  '198    Lari',
data.at[198, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lari_language'
#  '199    Páez',
data.at[199, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/P%C3%A1ez_language'
#  '201    Svan',
data.at[201, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Svan_language'
#  '208    Maori',
data.at[208, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/M%C4%81ori_language'
#  '215    Chamorro',
data.at[215, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chamorro_language'
#  '217    Chang',
data.at[217, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chang_language'
#  '249    Zaramo',
data.at[249, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zaramo_language'
#  '260    Irish',
data.at[260, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Irish_language'
#  '262    Sierra Otomí',
data.at[262, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sierra_Otom%C3%AD_language'
#  '265    Khalaj',
data.at[265, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khalaj_language'
#  '272    Kheng',
data.at[272, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kheng_language'
#  '273    Laro',
data.at[273, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laro_language'
#  '274    Minyong',
data.at[274, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Minyong_language'
#  '282    Khiamngan',
data.at[282, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khiamngan_language'
#  '295    Galo',
data.at[295, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Galo_language'
#  '304            Highland Mazatec',
data.at[304, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Highland_Mazatec'
#  '307    Mayo',
data.at[307, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mayo_language'
#  '312    Koch',
data.at[312, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koch_language'
#  '315    Bumthang',
data.at[315, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bumthang_language'
#  '319    Kham',
data.at[319, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kham_language'
#  '321    Lepcha',
data.at[321, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lepcha_language'
#  '324    Moro',
data.at[324, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moro_language'
#  '325     Mulam',
data.at[325, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mulam_language'
#  '328    Quichua (Pastaza)',
data.at[328, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Quichua_language'
#  '333    Toba',
data.at[333, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Toba_language'
#  '341    Ghale',
data.at[341, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ghale_language'
#  '344    Deori',
data.at[344, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Deori_language'
#  '347    Sibe',
data.at[347, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sibe_language'
#  '354    Koda',
data.at[354, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koda_language'
#  '363    Majhi',
data.at[363, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Majhi_language'
#  '364    Jone',
data.at[364, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jone_language'
#  '365    Andi',
data.at[365, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Andi_language'
#  '366    Guambiano',
data.at[366, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guambiano_language'
#  '373    Mara',
data.at[373, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mara_language'
#  '376    Sarikoli',
data.at[376, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sarikoli_language'
#  '379    Khunsari',
data.at[379, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Khunsari_language'
#  '380    Semnani',
data.at[380, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Semnani_language'
#  '304            Highland Mazatec',
data.at[304, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Highland_Mazatec'
#  '387    Bru',
data.at[387, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bru_language'
#  '401    Yaghnobi',
data.at[401, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yaghnobi_language'
#  '404     Boro',
data.at[404, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Boro_language'
#  '409    Kati',
data.at[409, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kati_language'
#  '410    Kulung',
data.at[410, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kulung_language'
#  '411    Kaingang',
data.at[411, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaingang_language'
#  '414    Bassari',
data.at[414, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bassari_language'
#  '423    Amba',
data.at[423, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Amba_language'
#  '425    Bonan',
data.at[425, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bonan_language'
#  '432    Hlersu',
data.at[432, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hlersu_language'
#  '438    Nahali',
data.at[438, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nahali_language'
#  '443    Rao',
data.at[443, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rao_language'
#  '451    Kuruba',
data.at[451, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuruba_language'
#  '453    Katla',
data.at[453, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Katla_language'
#  '462    Dondo',
data.at[462, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dondo_language'
#  '466    Karko',
data.at[466, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karko_language'
#  '469    Kadaru',
data.at[469, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kadaru_language'
#  '476    Hill Miri',
data.at[476, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hill_Miri_language'
#  '478    Muya',
data.at[478, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Muya_language'
#  '486    Northern Totonac',
data.at[486, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Northern_Totonac_language'
#  '487    Komo',
data.at[487, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Komo_language'
#  '490    Idu',
data.at[490, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Idu_language'
#  '492      Machiguenga',
data.at[492, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Machiguenga_language'
#  '496    Noon',
data.at[496, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Noon_language'
#  '497    Sampang',
data.at[497, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sampang_language'
#  '504    Bongo',
data.at[504, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bongo_language'
#  '519    Karone',
data.at[519, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karone_language'
#  '525    Mojo',
data.at[525, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mojo_language'
#  '538    Taba',
data.at[538, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taba_language'
#  '539    Talu',
data.at[539, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Talu_language'
#  '545    Vidunda',
data.at[545, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Vidunda_language'
#  '547    Paloor',
data.at[547, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Paloor_language'
#  '106       Phula (China)',
data.at[106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Phula_language'
#  '561    Motuo Menba',
data.at[561, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Motuo_Menba_language'
#  '563    Zuni',
data.at[563, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Zuni_language'
#  '565    Tulishi',
data.at[565, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tulishi_language'
#  '576    Argobba',
data.at[576, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Argobba_language'
#  '577    Austral dialects',
data.at[577, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Austral_language'
#  '582    Kanga',
data.at[582, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kanga_language'
#  '592    Wampis',
data.at[592, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wampis_language'
#  '598    Chukchi',
data.at[598, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chukchi_language'
#  '600    Awa Cuaiquer',
data.at[600, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Awa_Cuaiquer_language'
#  '607    Asur',
data.at[607, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Asur_language'
#  '611    Gazi',
data.at[611, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gazi_language'
#  '619    Soi',
data.at[619, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Soi_language'
#  '625    Chara',
data.at[625, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chara_language'
#  '643    Dimme',
data.at[643, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dimme_language'
#  '649    Mawé',
data.at[649, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maw%C3%A9_language'
#  '650    Shor',
data.at[650, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shor_language'
#  '653    Keiga',
data.at[653, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Keiga_language'
#  '666    Western Apache',
data.at[666, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Western_Apache_language'
#  '668    Yazgulami',
data.at[668, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yazgulami_language'
#  '687    Dilling',
data.at[687, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dilling_language'
#  '689    Lafofa',
data.at[689, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lafofa_language'
#  '709    Kalasha',
data.at[709, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kalasha_language'
#  '710    Kami',
data.at[710, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kami_language'
#  '714    Kom',
data.at[714, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kom_language'
#  '717    Mak',
data.at[717, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mak_language'
#  "721       Mo'ang (China)",
data.at[721, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mo%27ang_language'
#  "721       Mo'ang (China)",
data.at[721, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mo%27ang_language'
#  '728    Pu',
data.at[728, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pu_language'
#  '731    Turi',
data.at[731, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Turi_language'
#  '734    Jirel',
data.at[734, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jirel_language'
#  '740    Kivallirmiutut',
data.at[740, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kivallirmiutut_language'
#  '492      Machiguenga',
data.at[492, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Machiguenga_language'
#  '755    Tafi',
data.at[755, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tafi_language'
#  '756    Puma',
data.at[756, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Puma_language'
#  '757    Gyele',
data.at[757, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gyele_language'
#  '763     Aka',
data.at[763, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aka_language'
#  '788    Baghati',
data.at[788, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baghati_language'
#  '792    Konni',
data.at[792, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Konni_language'
#  '808    Crow',
data.at[808, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Crow_language'
#  '810    Shwai',
data.at[810, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Shwai_language'
#  '811    Wano',
data.at[811, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wano_language'
#  '816    Menik',
data.at[816, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Menik_language'
#  '819    Mursi',
data.at[819, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mursi_language'
#  '828    Benga',
data.at[828, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Benga_language'
#  '830    Boni',
data.at[830, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Boni_language'
#  '838    Geta?',
data.at[838, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Geta_language'
#  '839    Gura',
data.at[839, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gura_language'
#  '842    Jemez',
data.at[842, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jemez_language'
#  '843    Kamara',
data.at[843, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kamara_language'
#  '844    Kapingamarangi',
data.at[844, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kapingamarangi_language'
#  '846    Kuk',
data.at[846, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuk_language'
#  '847    Lai',
data.at[847, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lai_language'
#  '853    Nanay',
data.at[853, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nanay_language'
#  "854    Palu'e",
data.at[854, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Palu%27e_language'
#  '860    Savi',
data.at[860, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Savi_language'
#  '871    Jersey French',
data.at[871, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jersey_French'
#  '872    Bahing',
data.at[872, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bahing_language'
#  '873    Stoney',
data.at[873, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Stoney_language'
#  '876    Bisu',
data.at[876, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bisu_language'
#  '877     Wari',
data.at[877, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wari_language'
#  '878    Pakan',
data.at[878, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pakan_language'
#  '880    Ko',
data.at[880, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ko_language'
#  '885    Bolo',
data.at[885, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bolo_language'
#  '887    Sila',
data.at[887, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sila_language'
#  '889    Xerente',
data.at[889, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xerente_language'
#  '892    Bai',
data.at[892, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bai_language'
#  '893    Banka',
data.at[893, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Banka_language'
#  '894      Culina (Peru)',
data.at[894, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Culina_language'
#  '897      Laomian (China)',
data.at[897, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laomian_language'
#  '897      Laomian (China)',
data.at[897, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Laomian_language'
#  '914    Raji',
data.at[914, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Raji_language'
#  '934    Tiwi',
data.at[934, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tiwi_language'
#  '937    Aiton',
data.at[937, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aiton_language'
#  '942    Ata',
data.at[942, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ata_language'
#  '948    Bori',
data.at[948, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bori_language'
#  '894      Culina (Peru)',
data.at[894, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Culina_language'
#  '960    Ik',
data.at[960, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ik_language'
#  '965    Kona',
data.at[965, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kona_language'
#  '968    Kota',
data.at[968, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kota_language'
#  '971    Luro',
data.at[971, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Luro_language'
#  '972    Mambai',
data.at[972, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mambai_language'
#  '973    Milang',
data.at[973, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Milang_language'
#  '974    Mocoví',
data.at[974, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mocov%C3%AD_language'
#  '975    Momuna',
data.at[975, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Momuna_language'
#  '976    Mpi',
data.at[976, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mpi_language'
#  '977    Muda',
data.at[977, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Muda_language'
#  '984    Prasun',
data.at[984, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Prasun_language'
#  '995    Tchitchege',
data.at[995, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tchitchege_language'
#  '999    Urarina',
data.at[999, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Urarina_language'
#  '1018    Darma',
data.at[1018, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Darma_language'
#  '1019    Kung',
data.at[1019, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kung_language'
#  '1022    Pasing',
data.at[1022, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pasing_language'
#  '1024    Andio',
data.at[1024, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Andio_language'
#  '1029    Côông',
data.at[1029, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/C%C3%B4%C3%B4ng_language'
#  '1051    Jeri',
data.at[1051, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jeri_language'
#  '1059    Lishpa',
data.at[1059, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lishpa_language'
#  '1078    Tese',
data.at[1078, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tese_language'
#  '1082    Saba',
data.at[1082, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Saba_language'
#  '1096    Maxakali',
data.at[1096, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maxakal%C3%AD_language'
#  '1097    Murik',
data.at[1097, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Murik_language'
#  '1101    Besme',
data.at[1101, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Besme_language'
#  '1106    Dakka',
data.at[1106, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dakka_language'
#  "1109    Te'un (Seram Island)",
data.at[1109, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Te%27un_language'
#  '1110    Tsou',
data.at[1110, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tsou_language'
#  '1134    Western Náhuatl',
data.at[1134, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Western_N%C3%A1huatl'
#  '1144    Bola',
data.at[1144, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bola_language'
#  "1145    Bong'om",
data.at[1145, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bong%27om_language'
#  '1146    Bora',
data.at[1146, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bora_language'
#  '1148    Chali',
data.at[1148, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chali_language'
#  '1155    Ega',
data.at[1155, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ega_language'
#  '1169    Hung',
data.at[1169, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hung_language'
#  '1170    Ishkashimi',
data.at[1170, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ishkashimi_language'
#  "1174    Kaco'",
data.at[1174, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaco%27_language'
#  '1175    Kadu',
data.at[1175, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kadu_language'
#  '1177    Kari',
data.at[1177, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kari_language'
#  '1182    Kukatja',
data.at[1182, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kukatja_language'
#  '1187    May',
data.at[1187, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/May_language'
#  '1188    Mbara',
data.at[1188, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mbara_language'
#  '1189    Mech',
data.at[1189, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mech_language'
#  '1201    She',
data.at[1201, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/She_language'
#  '1208    Toto',
data.at[1208, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Toto_language'
#  '1221    Kunwinjku',
data.at[1221, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kunwinjku_language'
#  '1229    Mewahang',
data.at[1229, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mewahang_language'
#  '1234    Pech',
data.at[1234, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pech_language'
#  '1236    Caac',
data.at[1236, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Caac_language'
#  '1244    Mixtec of Santa Cruz Itundujia',
data.at[1244, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mixtec_of_Santa_Cruz_Itundujia'
#  '1248    Lola',
data.at[1248, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lola_language'
#  '1251    Bati',
data.at[1251, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bati_language'
#  '1253    Eman',
data.at[1253, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Eman_language'
#  '1254    Isu',
data.at[1254, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Isu_language'
#  '1260    Taos',
data.at[1260, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taos_language'
#  '1275      Nambiquara do Sul',
data.at[1275, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nambiquara_do_Sul_language'
#  '1280    Batek',
data.at[1280, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Batek_language'
#  '1281    Enggano',
data.at[1281, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Enggano_language'
#  '1292    Dakota',
data.at[1292, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dakota_language'
#  '1293    Carrier',
data.at[1293, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Carrier_language'
#  '1310    Hodi',
data.at[1310, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hodi_language'
#  '1312    Koke',
data.at[1312, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koke_language'
#  '1318    Penrhyn',
data.at[1318, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Penrhyn_language'
#  '1319    Pintupi',
data.at[1319, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pintupi_language'
#  '1350    Archi',
data.at[1350, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Archi_language'
#  '1353    Seri',
data.at[1353, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Seri_language'
#  '1364    Arbanasi',
data.at[1364, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arbanasi_language'
#  '1368    Black Mountain',
data.at[1368, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Black_Mountain_language'
#  '1381    Langa',
data.at[1381, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Langa_language'
#  '1393    Seke',
data.at[1393, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Seke_language'
#  '1404    Ulwa',
data.at[1404, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ulwa_language'
#  '1411    Wali',
data.at[1411, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wali_language'
#  '1412        Gavião do Pará',
data.at[1412, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gavi%C3%A3o_do_Par%C3%A1_language'
#  '1412        Gavião do Pará',
data.at[1412, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gavi%C3%A3o_do_Par%C3%A1_language'
#  '1439    Moose Cree',
data.at[1439, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moose_Cree_language'
#  '1440    Tlahuica',
data.at[1440, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tlahuica_language'
#  '1445    Buga',
data.at[1445, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Buga_language'
#  '1465    Ndunda',
data.at[1465, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ndunda_language'
#  '1468    Rapa',
data.at[1468, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rapa_language'
#  '1488    Labo',
data.at[1488, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Labo_language'
#  '1495    Mako',
data.at[1495, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mako_language'
#  '117     Alpine Provençal',
data.at[117, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Alpine_Proven%C3%A7al'
#  '1501    Thompson',
data.at[1501, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Thompson_language'
#  '1275      Nambiquara do Sul',
data.at[1275, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nambiquara_do_Sul_language'
#  '1511    Apalai',
data.at[1511, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Apalai_language'
#  '1516    Panará',
data.at[1516, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Panar%C3%A1_language'
#  '763     Aka',
data.at[763, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aka_language'
#  '1536    Mani',
data.at[1536, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mani_language'
#  '1538    Mono',
data.at[1538, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mono_language'
#  '1548    Tol',
data.at[1548, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tol_language'
#  '1555    Waru',
data.at[1555, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waru_language'
#  '1562    Guajá',
data.at[1562, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Guaj%C3%A1_language'
#  '1583    Ruc',
data.at[1583, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ruc_language'
#  '1584    Sause',
data.at[1584, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sause_language'
#  '1592    As',
data.at[1592, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/As_language'
#  '1598    Neku',
data.at[1598, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Neku_language'
#  '1599    Tiri',
data.at[1599, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tiri_language'
#  '1606    Karo',
data.at[1606, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karo_language'
#  '1609    Aja',
data.at[1609, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aja_language'
#  '1611    Bana',
data.at[1611, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bana_language'
#  '1612    Baras',
data.at[1612, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baras_language'
#  '1620    Doga',
data.at[1620, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Doga_language'
#  '1626    Hayu',
data.at[1626, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hayu_language'
#  '1627    Hidatsa',
data.at[1627, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hidatsa_language'
#  '1629    Iwaidja',
data.at[1629, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Iwaidja_language'
#  '1631    Kao',
data.at[1631, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kao_language'
#  '1606    Karo',
data.at[1606, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karo_language'
#  '1633    Kelo',
data.at[1633, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kelo_language'
#  '1638    Maung',
data.at[1638, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maung_language'
#  '1640    Moghol',
data.at[1640, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moghol_language'
#  '1650    Sauk-Fox',
data.at[1650, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sauk-Fox_language'
#  '1651    Sepa',
data.at[1651, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sepa_language'
#  '1674    Koro',
data.at[1674, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Koro_language'
#  '1680    Kaska',
data.at[1680, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kaska_language'
#  '1687    Baki',
data.at[1687, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Baki_language'
#  '1692    Hiw',
data.at[1692, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hiw_language'
#  '1694    Ket',
data.at[1694, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ket_language'
#  '877     Wari',
data.at[877, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wari_language'
#  '1710    Wab',
data.at[1710, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wab_language'
#  '1725    Yuki',
data.at[1725, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yuki_language'
#  '1726    Asurini do Xingu',
data.at[1726, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Asurini_do_Xingu_language'
#  '1736    Samre',
data.at[1736, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Samre_language'
#  '1745    Arem',
data.at[1745, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arem_language'
#  '1747    Bara (Colombia)',
data.at[1747, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bara_(Colombia)_language'
#  '1753    Dabra',
data.at[1753, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dabra_language'
#  '1762    Karas',
data.at[1762, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karas_language'
#  '1766    Maricopa',
data.at[1766, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Maricopa_language'
#  '1769    Molo',
data.at[1769, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Molo_language'
#  '325     Mulam',
data.at[325, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mulam_language'
#  '1772    Nafi',
data.at[1772, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nafi_language'
#  '1782    Sahaptin',
data.at[1782, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sahaptin_language'
#  '1783    Samatao',
data.at[1783, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Samatao_language'
#  '1789    Soo',
data.at[1789, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Soo_language'
#  '1794    Tirahi',
data.at[1794, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tirahi_language'
#  '1798    Xokleng',
data.at[1798, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Xokleng_language'
#  '1804    Usu',
data.at[1804, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Usu_language'
#  '1806    Ngarinyin',
data.at[1806, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngarinyin_language'
#  '1814    Ak',
data.at[1814, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ak_language'
#  '1816    Ari',
data.at[1816, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ari_language'
#  '1821    Mari',
data.at[1821, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mari_language'
#  '1824    Tobati',
data.at[1824, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tobati_language'
#  '1825    Moré',
data.at[1825, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mor%C3%A9_language'
#  '1826    Mores',
data.at[1826, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mores_language'
#  '1827    Musan',
data.at[1827, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Musan_language'
#  '1828    Papi',
data.at[1828, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Papi_language'
#  '1846    Bothar',
data.at[1846, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bothar_language'
#  '1858    Gooniyandi',
data.at[1858, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gooniyandi_language'
#  '1873    Moere',
data.at[1873, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Moere_language'
#  '1883    Bella Coola',
data.at[1883, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bella_Coola_language'
#  '1896    Miriwoong',
data.at[1896, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Miriwoong_language'
#  '1904    Patua',
data.at[1904, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Patua_language'
#  '1910    Salas',
data.at[1910, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Salas_language'
#  '1912    Sapé',
data.at[1912, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sap%C3%A9_language'
#  '1914    Sian',
data.at[1914, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sian_language'
#  '1927    Bunuba',
data.at[1927, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bunuba_language'
#  '1932    Mono (Western)',
data.at[1932, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mono_(Western)_language'
#  '1933    Southern Tutchone',
data.at[1933, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Southern_Tutchone_language'
#  '1938    Noy',
data.at[1938, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Noy_language'
#  '1948    Jarawa',
data.at[1948, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jarawa_language'
#  '1954    Bardi',
data.at[1954, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bardi_language'
#  '1957    Carijona',
data.at[1957, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Carijona_language'
#  '1961    Duriankere',
data.at[1961, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Duriankere_language'
#  '1932    Mono (Western)',
data.at[1932, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mono_(Western)_language'
#  '1983    Mor',
data.at[1983, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mor_language'
#  '1987    Upper Kuskokwim',
data.at[1987, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Upper_Kuskokwim_language'
#  '1993    Kuku Yalanji',
data.at[1993, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kuku_Yalanji_language'
#  '1994    Sām',
data.at[1994, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/S%C4%81m_language'
#  '1747    Bara (Colombia)',
data.at[1747, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bara_(Colombia)_language'
#  '2002    Bom',
data.at[2002, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bom_language'
#  '2008    Hermit',
data.at[2008, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hermit_language'
#  '2009    Jawoyn',
data.at[2009, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jawoyn_language'
#  '2014    Kim',
data.at[2014, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kim_language'
#  '2020    Mangarla',
data.at[2020, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Mangarla_language'
#  '2025    Nyamal',
data.at[2025, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nyamal_language'
#  '2026    Nyikina',
data.at[2026, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Nyikina_language'
#  '2027    Panamint',
data.at[2027, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Panamint_language'
#  '2034    Vote',
data.at[2034, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Vote_language'
#  '2035    Wajarri',
data.at[2035, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wajarri_language'
#  '2046    Jaminjung',
data.at[2046, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Jaminjung_language'
#  '2054    Aruá',
data.at[2054, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Aru_languages'
#  '2055    Han (United States of America)',
data.at[2055, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Han_(United_States_of_America)_language'
#  '2060    Ngaliwuru',
data.at[2060, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngaliwuru_language'
#  '2076    Hoti',
data.at[2076, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hoti_language'
#  '2078    Ibu',
data.at[2078, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ibu_language'
#  '2081    Karajarri',
data.at[2081, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karajarri_language'
#  '2082    Karipuna',
data.at[2082, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Karipuna_language'
#  '2086    Kurrama',
data.at[2086, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kurrama_language'
#  '2088    Lom',
data.at[2088, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lomavren_language'
#  '2090    Madngele',
data.at[2090, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Matngala_language#:~:text=Matngele%20or%20Madngele%20is%20an,the%20Madngella%20and%20Yunggor%20peoples.'
#  '2102    Ngardi',
data.at[2102, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngardi_language'
#  '2108    Osage',
data.at[2108, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Osage_language'
#  '2110    Pawnee',
data.at[2110, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Pawnee_language'
#  '2112    Rembarrnga',
data.at[2112, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Rembarrnga_language'
#  '2113    Sene',
data.at[2113, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sene_language'
#  '2117    Tape',
data.at[2117, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tape_language'
#  '2119    Thao',
data.at[2119, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Thao_language'
#  '2122    Wichita',
data.at[2122, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wichita_language'
#  '2125    Yiiji',
data.at[2125, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yiiji_language'
#  '2126    Arára Shawãdáwa',
data.at[2126, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ar%C3%A1ra_Shaw%C3%A3d%C3%A1wa_language'
#  '2129    Ngarluma',
data.at[2129, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngarluma_language'
#  '2146    Arabana',
data.at[2146, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arabana_language'
#  '2153    Abaga',
data.at[2153, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Abaga_language'
#  '2167    Juma',
data.at[2167, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Juma_language'
#  '2169    Kanoê',
data.at[2169, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kano%C3%AA_language'
#  '2175    Naman',
data.at[2175, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Naman_language'
#  '2178    Ndai',
data.at[2178, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ndai_language'
#  '2190    Vano',
data.at[2190, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Vano_language'
#  '2191    Wunambal',
data.at[2191, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Wunambal_language'
#  "2194    Coeur d'Alene",
data.at[2194, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Coeur_d%27Alene_language'
#  '2199    Ouma',
data.at[2199, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ouma_language'
#  '2205    Waanyi',
data.at[2205, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Waanyi_language#:~:text=Waanyi%2C%20also%20spelt%20Wanyi%2C%20Wanji,16%20speakers%20of%20the%20language.'
#  '2206    Worrorra',
data.at[2206, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Worrorra_language'
#  '2209    Bung',
data.at[2209, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bung_language'
#  '2225    Ura',
data.at[2224, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ura_language_(Papua_New_Guinea)'
#  '2234    Klallam',
data.at[2234, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Klallam_language'
#  '2239    Luri',
data.at[2239, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Luri_language'
#  '2245    Sambe',
data.at[2245, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sambe_language'
#  '2254    Chaná',
data.at[2254, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Chan%C3%A1_language'
#  '2255    Dampel',
data.at[2255, 'Wikipedia URL'] = None
#  '2260    Patwin',
data.at[2260, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Patwin_language'
#  '2264    Tinigua',
data.at[2264, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tinigua_language'
#  '2266    Uru',
data.at[2266, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Uru_language'
#  '2281    Antoniano',
data.at[2281, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Salinan_language'
#  '2283    Apolista',
data.at[2283, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lapachu_language'
#  '2287    Arin',
data.at[2287, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arin_language'
#  '2289    Arta',
data.at[2289, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Arta_language'
#  '2301    Berti',
data.at[2301, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Berti_language'
#  '2302    Bina',
data.at[2302, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Bina_language'
#  '404     Boro',
data.at[404, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Boro_language_(India)'
#  '2308    Catawba',
data.at[2308, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Catawba_language'
#  '2313    Cholon',
data.at[2313, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Cholon_language'
#  '2326    Duli',
data.at[2326, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Duli_language'
#  '2328    Dura',
data.at[2328, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Dura_language'
#  '2333    Eliri',
data.at[2333, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Eliri_language'
#  '2343    Gothic',
data.at[2343, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gothic_language'
#  '2345    Gule',
data.at[2345, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Gule_language'
#  '2350    Hoanya',
data.at[2350, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Hoanya_language'
#  '2351    Homa',
data.at[2351, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Homa_language'
#  '2366    Kansa',
data.at[2366, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kansa_language'
#  '2371    Kato',
data.at[2371, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kato_language'
#  '2377    Kerek',
data.at[2377, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kerek_language'
#  '2384    Kore',
data.at[2384, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kore_language'
#  '2385    Kott',
data.at[2385, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kott_language'
#  '2388    Kulun',
data.at[2388, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kulun_language'
#  '2393    Kyakala',
data.at[2393, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Kyakala_language'
#  '2399    Lipan',
data.at[2399, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Lipan_language'
#  '2406    Máku',
data.at[2406, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/M%C3%A1ku_language'
#  '2407    Malin',
data.at[2407, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Malin_language'
#  '2422    Molala',
data.at[2422, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Molala_language'
#  '2428    Natchez',
data.at[2428, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Natchez_language'
#  '2430    Ngarla',
data.at[2430, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngarla_language'
#  '2431    Ngong',
data.at[2431, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ngong_language'
#  '2435    Norn',
data.at[2435, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Norn_language'
#  '2445    Ona',
data.at[2445, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Ona_language'
#  '2455    Piru',
data.at[2455, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Piru_language'
#  '2464    Sei',
data.at[2464, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Sei_language'
#  '2467    Serrano',
data.at[2467, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Serrano_language'
#  '2470    Singa',
data.at[2470, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Singa_language'
#  '2481    Taman',
data.at[2481, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Taman_language_(Myanmar)'
#  "1109    Te'un (Seram Island)",
data.at[1109, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Teun_language'
#  '2490    Tsetsaut',
data.at[2490, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tsetsaut_language'
#  '2492    Tututni',
data.at[2492, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Tututni_language'
#  '2502    Vilela',
data.at[2502, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Vilela_language'
#  '2513    Yola',
data.at[2513, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yola_language'
#  '1725    Yuki'
data.at[1725, 'Wikipedia URL'] = 'https://en.wikipedia.org/wiki/Yuki_language'

# %%
def find_index_of_headers(url):
    response        = requests.get(url)
    content         = response.content
    parser          = BeautifulSoup(content, 'html.parser')
    table           = parser.find('table', {'class': 'infobox'})
    included_headers = {}
    
    for i in range(0, len(table.find_all('th', {'class': 'infobox-label'}))):
        included_headers[unicodedata.normalize('NFKD', table.find_all('th', {'class': 'infobox-label'}).__getitem__(i).getText())] = i
    return included_headers


urls = pd.read_csv('../extinct_languages_with_links.csv')['Wikipedia URL'].to_list()

urls = list(set(urls))

# urls = [url for url in urls if url not in ['Official_language', 'Minority_language']]
# urls = [url for url in urls if url.startswith('List_of_countries') == False]
# urls = [url for url in urls if url.count(':') == 1]
# urls = [url for url in urls if '?' not in url]

# %%
data = []
errors = []
invalid_links = []

for url in tqdm(urls): 
    # try: 
        lang = url.split('/')[-1]

        # print(requests.get(url).status_code)
        # print(url)
        response        = requests.get(url)
        content         = response.content
        parser          = BeautifulSoup(content, 'html.parser')
        table           = parser.find('table', {'class': 'infobox'})

        if table == None:
             invalid_links.append(url)
            #  print("No table found ", url)
             continue

        header_indices  = find_index_of_headers(url)

        # print(header_indices)

        infobox_data = table.find_all('td', {'class': 'infobox-data'})

        lang            = table.find('th', {'class': 'infobox-above above'}).get_text('title') if table.find('th', {'class': 'infobox-above above'}) else lang

        off_lang        = infobox_data[header_indices['Official language in']].text if 'Official language in' in header_indices else None
        rec_min_lang    = infobox_data[header_indices['Recognised minoritylanguage in']].text if 'Recognised minoritylanguage in' in header_indices else None
        # speakers        = infobox_data[header_indices['Speakers']].text             if 'Speakers' in header_indices else None
        iso3code        = infobox_data[header_indices['ISO 639-3']].get_text('title')            if 'ISO 639-3' in header_indices else None
        glottocode      = infobox_data[header_indices['Glottolog']].get_text('title')            if 'Glottolog' in header_indices else None

        if 'Speakers' in header_indices.keys():
            speakers = infobox_data[header_indices['Speakers']].text
        elif 'Native speakers' in header_indices.keys():
            speakers = infobox_data[header_indices['Native speakers']].text
        else:
            speakers = None

        if 'Region' in header_indices.keys():
            regions = infobox_data[header_indices['Region']].text
        elif 'Native Region' in header_indices.keys():
            regions = infobox_data[header_indices['Native Region']].text
        else:
            regions = None

        family          = [x for x in infobox_data[header_indices['Language family']].get_text('title').split('title') if x != "\n"]\
                            if 'Language family' in header_indices else None
        
        dialects        = [x for x in infobox_data[header_indices['Dialects']].get_text('title').split('title') if x != "\n"] \
                            if 'Dialects' in header_indices else None

        url             = str(url)
        
        # print('Regions: ', regions)

        data.append((lang, family, dialects, iso3code, glottocode, speakers, regions, off_lang, rec_min_lang, url))
    # except Exception as e: 
    #     errors.append((e, url))
    #     continue

df = pd.DataFrame(data, columns=['lang', 'family', 'dialects', 'iso3code', 'goglottocodettolog', 'speakers', 'regions', 'off_lang', 'rec_min_lang', 'url'])
# Out:
# 100%|██████████| 2261/2261 [25:49<00:00,  1.46it/s]

# %%
print(len(invalid_links))
print(invalid_links)
# Out:
# 434
# ...

# %%
df.to_csv('../extinct_languages_with_info.csv', index=False)

# %%
print(len(invalid_links))

data = pd.read_csv('../extinct_languages_with_links.csv')
invalid_links_updated = []

for link in invalid_links:
    lang = str(data[data['Wikipedia URL'] == link]['Name in English']).split('\n')[0]
    invalid_links_updated.append(lang)
    # index = data[data['Wikipedia URL'] == link].index[0]
    # invalid_links_updated.append([lang, index])

invalid_links_updated
# Out:
# 435
# ['1814    Ak',
#  '2345    Gule',
#  '687    Dilling',
#  '40    Mon',
#  '2399    Lipan',
#  '1177    Kari',
#  '2178    Ndai',
#  '315    Bumthang',
#  '1938    Noy',
#  '1914    Sian',
#  '1592    As',
#  '116    Komi',
#  '1110    Tsou',
#  '1051    Jeri',
#  '2102    Ngardi',
#  '2034    Vote',
#  '2308    Catawba',
#  '2393    Kyakala',
#  '1993    Kuku Yalanji',
#  '1828    Papi',
#  '2464    Sei',
#  '842    Jemez',
#  '710    Kami',
#  '1932    Mono (Western)',
#  '1753    Dabra',
#  '810    Shwai',
#  '885    Bolo',
#  '965    Kona',
#  '48    Picard',
#  '666    Western Apache',
#  '847    Lai',
#  '2289    Arta',
#  '972    Mambai',
#  '347    Sibe',
#  '1766    Maricopa',
#  '487    Komo',
#  '307    Mayo',
#  '2046    Jaminjung',
#  '11    Aymara',
#  '1789    Soo',
#  '649    Mawé',
#  '1516    Panará',
#  '1536    Mani',
#  '1538    Mono',
#  '668    Yazgulami',
#  '880    Ko',
#  '1961    Duriankere',
#  '538    Taba',
#  '1292    Dakota',
#  '2239    Luri',
# ...

# %%
df.isna().sum()
# Out:
# lang               0
# family           343
# dialects        1552
# iso3code         336
# speakers         516
# regions          663
# off_lang        1673
# rec_min_lang    1741
# dtype: int64

# %%
wiki_data = pd.read_csv('../wiki_languages_most_recent.csv')

merged = pd.merge()

# %% [markdown]
# ## The Following Languages Still Have Invalid Links
