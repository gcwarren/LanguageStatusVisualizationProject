# %%
import pandas as pd 
import requests
import unicodedata
import numpy as np 
from tqdm import tqdm
from bs4 import BeautifulSoup

# %%
x = 'Khoisan[i][77]'
x[:x.find('[')]
# Out:
# 'Khoisan'

# %%
list = (['Chewa', 'Chibarwe', 'English', 'Kalanga', 'Khoisan[i][77]', 'Nambya', 'Ndau', 'Ndebele', 'Shangani', 'Shona', \
         'Sign language[j]', 'Sotho', 'Tonga', 'Tswana', 'Venda', 'Xhosa'])
delimeter = ','
str = delimeter.join(list)
str.split('[')

# for item in list:
#     if item[0].isdigit():
#         list.remove(item)

# print(list)
# Out:
# ['Chewa,Chibarwe,English,Kalanga,Khoisan',
#  'i]',
#  '77],Nambya,Ndau,Ndebele,Shangani,Shona,Sign language',
#  'j],Sotho,Tonga,Tswana,Venda,Xhosa']

# %%
'Catalan[4]'.split('[')[1][0].isdigit()
# Out:
# True

# %%
countries_and_territories = requests.get('https://en.wikipedia.org/wiki/List_of_official_languages_by_country_and_territory')
# 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_and_their_capitals_in_native_languages'

soup = BeautifulSoup(countries_and_territories.content, 'html.parser')
table = soup.find('table', {'class': ['wikitable', 'sortable', 'jquery-tablesorter']})
languages_by_region = pd.DataFrame(columns=['Country/Region', 'Official Language', 'Regional Language', 'Minority Language', 'National Language', 'Widely Spoken'], index = range(0, len(table.find_all('tr')) - 1))
delimeter = ','

i = 0
for region in table.find('tbody').find_all('tr')[1:]:

    columns = region.find_all('td')

    if len(columns) != 6:
        languages_by_region.iloc[i] = [np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN]

# [item for item in delimeter.join(columns[0].text.strip().split('[')).split(delimeter) if (not item[0].isdigit() or not item.endswith(']'))]

    else:
        languages_by_region.loc[i, 'Country/Region'] = columns[0].text.strip().split('\n')
        languages_by_region.loc[i, 'Official Language'] = columns[1].text.strip().split('\n')
        languages_by_region.loc[i, 'Regional Language'] = columns[2].text.strip().split('\n')
        languages_by_region.loc[i, 'Minority Language'] = columns[3].text.strip().split('\n')
        languages_by_region.loc[i, 'National Language'] = columns[4].text.strip().split('\n')
        languages_by_region.loc[i, 'Widely Spoken'] = columns[5].text.strip().split('\n')

    i += 1

languages_by_region.iloc[21] = [['Bolivia'], ['Castilian (Spanish)', 'Aymara', 'Araona', 'Baure', 'Bésiro (Chiquitano)', 'Canichana', \
                                            'Cavineña', 'Cayubaba', 'Chácobo', 'Chimán', 'Ese Ejja', 'Guaraní', 'Guarasu\'we', 'Guarayu', \
                                            'Itonama', 'Leco', 'Machajuyai-Kallawaya', 'Machineri', 'Maropa', 'Mojeño-Ignaciano', 'Mojeño-Trinitario', \
                                            'Moré', 'Mosetén', 'Movima', 'Pacawara', 'Puquina', 'Quechua', 'Sirionó', 'Tacana', 'Tapieté', 'Toromona', \
                                            'Uru-Chipaya', 'Weenhayek', 'Yaminawa', 'Yuki', 'Yuracaré', 'Zamuco'], \
                                [''], [''], [''], ['']]
languages_by_region.iloc[180] = [['Sweden'], ['Swedish'], [' '], ['Finnish (Gällivare, Haparanda, Kiruna, Pajala, Övertorneå)', \
                                                            'Meänkieli (Gällivare, Haparanda, Kiruna, Pajala, Övertorneå)', \
                                                            'Sami (Arjeplog, Gällivare, Jokkmokk, Kiruna)', 'Yiddish', 'Romani'], 'English', ' ']
languages_by_region.iloc[195] = [['Tuvalu'], ['Tuvaluan', 'English'], [''], [''], ['Tuvaluan', 'English'], ['']]
languages_by_region.iloc[208] = [['Zambia'], ['English'], [''], [''], [''], ['']]

languages_by_region['Country/Region'] = languages_by_region['Country/Region'].apply(lambda x: delimeter.join([item for item in delimeter.join(x).split('[') if (not item[0].isdigit() and not item.endswith(']'))]))
# languages_by_region['Official Language'] = languages_by_region['Official Language'].apply(lambda x: [item for item in delimeter.join(x).split('[') if (not item[0].isdigit() or not item.endswith(']'))])


languages_by_region
# Out:
# /Users/fsultan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
#     Country/Region                                  Official Language  \
# 0         Abkhazia                                  [Abkhaz, Russian]
# 1      Afghanistan                           [Persian (Dari), Pashto]
# 2          Albania                                         [Albanian]
# 3          Algeria                                   [Arabic, Berber]
# 4          Andorra                                       [Catalan[4]]
# ..             ...                                                ...
# 205      Venezuela                [Spanish, Venezuelan Sign Language]
# 206        Vietnam                                       [Vietnamese]
# 207          Yemen                                           [Arabic]
# 208         Zambia                                          [English]
# 209       Zimbabwe  [Chewa, Chibarwe, English, Kalanga, Khoisan[i]...
#
#                                      Regional Language  \
# 0                                                   []
# 1    [Uzbek[b], Turkmen[b], Pashayi[b], Nuristani[b...
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 205                                                 []
# 206                                                 []
# 207                                                 []
# 208                                                 []
# 209                                                 []
#
#                                      Minority Language  \
# 0                                           [Georgian]
# 1                                                   []
# 2                       [Greek, Macedonian, Aromanian]
# 3                                                   []
# 4                        [Spanish, French, Portuguese]
# ..                                                 ...
# 205  [Native languages are official for indigenous ...
# 206  [Cantonese, Cham, Hmong, Khmer, Lao, Muong, Ra...
# 207                                   [Mehri, Soqotri]
# 208                                                 []
# 209                                                 []
#
#             National Language     Widely Spoken
# 0                    [Abkhaz]                []
# 1    [Persian (Dari), Pashto]  [Persian (Dari)]
# 2                          []         [Italian]
# 3            [Arabic, Berber]          [French]
# 4                          []                []
# ..                        ...               ...
# 205                        []                []
# 206              [Vietnamese]                []
# 207                        []                []
# 208                        []                []
# 209                        []                []
#
# [210 rows x 6 columns]

# %%
languages_by_region
# Out:
#     Country/Region                                  Official Language  \
# 0         Abkhazia                                  [Abkhaz, Russian]
# 1      Afghanistan                           [Persian (Dari), Pashto]
# 2          Albania                                         [Albanian]
# 3          Algeria                                   [Arabic, Berber]
# 4          Andorra                                       [Catalan[4]]
# ..             ...                                                ...
# 205      Venezuela                [Spanish, Venezuelan Sign Language]
# 206        Vietnam                                       [Vietnamese]
# 207          Yemen                                           [Arabic]
# 208         Zambia                                          [English]
# 209       Zimbabwe  [Chewa, Chibarwe, English, Kalanga, Khoisan[i]...
#
#                                      Regional Language  \
# 0                                                   []
# 1    [Uzbek[b], Turkmen[b], Pashayi[b], Nuristani[b...
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 205                                                 []
# 206                                                 []
# 207                                                 []
# 208                                                 []
# 209                                                 []
#
#                                      Minority Language  \
# 0                                           [Georgian]
# 1                                                   []
# 2                       [Greek, Macedonian, Aromanian]
# 3                                                   []
# 4                        [Spanish, French, Portuguese]
# ..                                                 ...
# 205  [Native languages are official for indigenous ...
# 206  [Cantonese, Cham, Hmong, Khmer, Lao, Muong, Ra...
# 207                                   [Mehri, Soqotri]
# 208                                                 []
# 209                                                 []
#
#             National Language     Widely Spoken
# 0                    [Abkhaz]                []
# 1    [Persian (Dari), Pashto]  [Persian (Dari)]
# 2                          []         [Italian]
# 3            [Arabic, Berber]          [French]
# 4                          []                []
# ..                        ...               ...
# 205                        []                []
# 206              [Vietnamese]                []
# 207                        []                []
# 208                        []                []
# 209                        []                []
#
# [210 rows x 6 columns]

# %%
cols = languages_by_region.columns[1:]
for col in cols: 
    languages_by_region[col] = languages_by_region[col].apply(lambda values: [x[:x.find('[')] if '[' in x else x for x in values])

# %%
languages_by_region.to_csv('languages_by_region.csv', index=False)
